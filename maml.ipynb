# %% [markdown]
# <a href="https://colab.research.google.com/github/kiranikram/NYC-Traffic-Jams-/blob/master/maml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/CLASSIFICATION/Few Shot')
# %cd '/content/drive/My Drive/CLASSIFICATION/Few Shot'
# Out:
# /content/drive/My Drive/CLASSIFICATION/Few Shot

# %% [markdown]
# # Requirements

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch
from torch import nn
from torch.nn import Module
from PIL import Image
from torchvision import transforms
from skimage import io
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import argparse
from collections import OrderedDict, Iterable
import io
from collections import OrderedDict
from torch.optim import Optimizer
from torch.utils.data import Sampler
from typing import List, Iterable, Callable, Tuple, Union, Dict
import torch.nn.functional as F
import shutil
import csv
import os

# %% [markdown]
# # few_shot.datasets_aircraft

# %%
#from few_shot.datasets_aircraft import Aircraft
class Aircraft(Dataset):
    def __init__(self, subset):
        """Dataset class representing miniImageNet dataset

        # Arguments:
            subset: Whether the dataset represents the background or evaluation set
        """
        if subset not in ('background', 'evaluation'):
            raise(ValueError, 'subset must be one of (background, evaluation)')
        self.subset = subset

        self.df = pd.DataFrame(self.index_subset(self.subset))

        # Index of dataframe has direct correspondence to item in dataset
        self.df = self.df.assign(id=self.df.index.values)

        # Convert arbitrary class names of dataset to ordered 0-(num_speakers - 1) integers
        self.unique_characters = sorted(self.df['class_name'].unique())
        self.class_name_to_id = {self.unique_characters[i]: i for i in range(self.num_classes())}
        self.df = self.df.assign(class_id=self.df['class_name'].apply(lambda c: self.class_name_to_id[c]))

        # Create dicts
        self.datasetid_to_filepath = self.df.to_dict()['filepath']
        self.datasetid_to_class_id = self.df.to_dict()['class_id']

        # Setup transforms
        self.transform = transforms.Compose([
            transforms.CenterCrop(224),
            transforms.Resize(84),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
        ])

    def __getitem__(self, item):
        #print(item)
        instance = Image.open(self.datasetid_to_filepath[item])
        instance = self.transform(instance)
        label = self.datasetid_to_class_id[item]
        return instance, label

    def __len__(self):
        return len(self.df)

    def num_classes(self):
        return len(self.df['class_name'].unique())

    @staticmethod
    def index_subset(subset):
        """Index a subset by looping through all of its files and recording relevant information.

        # Arguments
            subset: Name of the subset

        # Returns
            A list of dicts containing information about all the image files in a particular subset of the
            miniImageNet dataset
        """
        images = []
        print('Indexing {}...'.format(subset))
        # Quick first pass to find total for tqdm bar
        subset_len = 0
        for root, folders, files in os.walk(DATA_PATH + '/aircrafts/images_{}/'.format(subset)):
            subset_len += len([f for f in files if f.endswith('.png')])

        progress_bar = tqdm(total=subset_len)
        for root, folders, files in os.walk(DATA_PATH + '/aircrafts/images_{}/'.format(subset)):
            if len(files) == 0:
                continue

            class_name = root.split('/')[-1]

            for f in files:
                progress_bar.update(1)
                images.append({
                    'subset': subset,
                    'class_name': class_name,
                    'filepath': os.path.join(root, f)
                })

        progress_bar.close()
        return images

# %% [markdown]
# # few_shot.core

# %%
#from few_shot.metrics import categorical_accuracy
def categorical_accuracy(y, y_pred):
    """Calculates categorical accuracy.

    # Arguments:
        y_pred: Prediction probabilities or logits of shape [batch_size, num_categories]
        y: Ground truth categories. Must have shape [batch_size,]
    """
    return torch.eq(y_pred.argmax(dim=-1), y).sum().item() / y_pred.shape[0]


NAMED_METRICS = {
    'categorical_accuracy': categorical_accuracy
}

# %%
#from few_shot.eval import evaluate
def evaluate(model: Module, dataloader: DataLoader, prepare_batch: Callable, metrics: List[Union[str, Callable]],
             loss_fn: Callable = None, prefix: str = 'val_', suffix: str = ''):
    """Evaluate a model on one or more metrics on a particular dataset

    # Arguments
        model: Model to evaluate
        dataloader: Instance of torch.utils.data.DataLoader representing the dataset
        prepare_batch: Callable to perform any desired preprocessing
        metrics: List of metrics to evaluate the model with. Metrics must either be a named metric (see `metrics.py`) or
            a Callable that takes predictions and ground truth labels and returns a scalar value
        loss_fn: Loss function to calculate over the dataset
        prefix: Prefix to prepend to the name of each metric - used to identify the dataset. Defaults to 'val_' as
            it is typical to evaluate on a held-out validation dataset
        suffix: Suffix to append to the name of each metric.
    """
    logs = {}
    seen = 0
    totals = {m: 0 for m in metrics}
    if loss_fn is not None:
        totals['loss'] = 0
    model.eval()
    with torch.no_grad():
        for batch in dataloader:
            x, y = prepare_batch(batch)
            y_pred = model(x)

            seen += x.shape[0]

            if loss_fn is not None:
                totals['loss'] += loss_fn(y_pred, y).item() * x.shape[0]

            for m in metrics:
                if isinstance(m, str):
                    v = NAMED_METRICS[m](y, y_pred)
                else:
                    # Assume metric is a callable function
                    v = m(y, y_pred)

                totals[m] += v * x.shape[0]

    for m in ['loss'] + metrics:
        logs[prefix + m + suffix] = totals[m] / seen

    return logs

# %%
#from few_shot.callbacks import Callback
class Callback(object):
    def __init__(self):
        self.model = None

    def set_params(self, params):
        self.params = params

    def set_model(self, model):
        self.model = model

    def on_epoch_begin(self, epoch, logs=None):
        pass

    def on_epoch_end(self, epoch, logs=None):
        pass

    def on_batch_begin(self, batch, logs=None):
        pass

    def on_batch_end(self, batch, logs=None):
        pass

    def on_train_begin(self, logs=None):
        pass

    def on_train_end(self, logs=None):
        pass

# %%
class NShotTaskSampler(Sampler):
    def __init__(self,
                 dataset: torch.utils.data.Dataset,
                 episodes_per_epoch: int = None,
                 n: int = None,
                 k: int = None,
                 q: int = None,
                 num_tasks: int = 1,
                 fixed_tasks: List[Iterable[int]] = None):
        """PyTorch Sampler subclass that generates batches of n-shot, k-way, q-query tasks.

        Each n-shot task contains a "support set" of `k` sets of `n` samples and a "query set" of `k` sets
        of `q` samples. The support set and the query set are all grouped into one Tensor such that the first n * k
        samples are from the support set while the remaining q * k samples are from the query set.

        The support and query sets are sampled such that they are disjoint i.e. do not contain overlapping samples.

        # Arguments
            dataset: Instance of torch.utils.data.Dataset from which to draw samples
            episodes_per_epoch: Arbitrary number of batches of n-shot tasks to generate in one epoch
            n_shot: int. Number of samples for each class in the n-shot classification tasks.
            k_way: int. Number of classes in the n-shot classification tasks.
            q_queries: int. Number query samples for each class in the n-shot classification tasks.
            num_tasks: Number of n-shot tasks to group into a single batch
            fixed_tasks: If this argument is specified this Sampler will always generate tasks from
                the specified classes
        """
        super(NShotTaskSampler, self).__init__(dataset)
        self.episodes_per_epoch = episodes_per_epoch
        self.dataset = dataset
        if num_tasks < 1:
            raise ValueError('num_tasks must be > 1.')

        self.num_tasks = num_tasks
        # TODO: Raise errors if initialise badly
        self.k = k
        self.n = n
        self.q = q
        self.fixed_tasks = fixed_tasks

        self.i_task = 0

    def __len__(self):
        return self.episodes_per_epoch

    def __iter__(self):
        for _ in range(self.episodes_per_epoch):
            batch = []

            for task in range(self.num_tasks):
                if self.fixed_tasks is None:
                    # Get random classes
                    episode_classes = np.random.choice(self.dataset.df['class_id'].unique(), size=self.k, replace=False)
                else:
                    # Loop through classes in fixed_tasks
                    episode_classes = self.fixed_tasks[self.i_task % len(self.fixed_tasks)]
                    self.i_task += 1

                df = self.dataset.df[self.dataset.df['class_id'].isin(episode_classes)]

                support_k = {k: None for k in episode_classes}
                for k in episode_classes:
                    # Select support examples
                    support = df[df['class_id'] == k].sample(self.n)
                    support_k[k] = support

                    for i, s in support.iterrows():
                        batch.append(s['id'])

                for k in episode_classes:
                    #print('self.q', self.q)
                    #print('df[(df[...shape',df[(df['class_id'] == k) & (~df['id'].isin(support_k[k]['id']))].shape)
                    if df[(df['class_id'] == k) & (~df['id'].isin(support_k[k]['id']))].shape[0]==0:
                        query = []
                    else:
                        #print('its OK!!!!!!!!')
                        query = df[(df['class_id'] == k) & (~df['id'].isin(support_k[k]['id']))].sample(self.q)
                        for i, q in query.iterrows():
                            batch.append(q['id'])

            yield np.stack(batch)

# %%
class EvaluateFewShot(Callback):
    """Evaluate a network on  an n-shot, k-way classification tasks after every epoch.

    # Arguments
        eval_fn: Callable to perform few-shot classification. Examples include `proto_net_episode`,
            `matching_net_episode` and `meta_gradient_step` (MAML).
        num_tasks: int. Number of n-shot classification tasks to evaluate the model with.
        n_shot: int. Number of samples for each class in the n-shot classification tasks.
        k_way: int. Number of classes in the n-shot classification tasks.
        q_queries: int. Number query samples for each class in the n-shot classification tasks.
        task_loader: Instance of NShotWrapper class
        prepare_batch: function. The preprocessing function to apply to samples from the dataset.
        prefix: str. Prefix to identify dataset.
    """

    def __init__(self,
                 eval_fn: Callable,
                 num_tasks: int,
                 n_shot: int,
                 k_way: int,
                 q_queries: int,
                 taskloader: torch.utils.data.DataLoader,
                 prepare_batch: Callable,
                 prefix: str = 'val_',
                 **kwargs):
        super(EvaluateFewShot, self).__init__()
        self.eval_fn = eval_fn
        self.num_tasks = num_tasks
        self.n_shot = n_shot
        self.k_way = k_way
        self.q_queries = q_queries
        self.taskloader = taskloader
        self.prepare_batch = prepare_batch
        self.prefix = prefix
        self.kwargs = kwargs
        self.metric_name = f'{self.prefix}{self.n_shot}-shot_{self.k_way}-way_acc'

    def on_train_begin(self, logs=None):
        self.loss_fn = self.params['loss_fn']
        self.optimiser = self.params['optimiser']

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        seen = 0
        totals = {'loss': 0, self.metric_name: 0}
        for batch_index, batch in enumerate(self.taskloader):
            x, y = self.prepare_batch(batch)

            loss, y_pred = self.eval_fn(
                self.model,
                self.optimiser,
                self.loss_fn,
                x,
                y,
                n_shot=self.n_shot,
                k_way=self.k_way,
                q_queries=self.q_queries,
                train=False,
                **self.kwargs
            )

            seen += y_pred.shape[0]

            totals['loss'] += loss.item() * y_pred.shape[0]
            totals[self.metric_name] += categorical_accuracy(y, y_pred) * y_pred.shape[0]

        logs[self.prefix + 'loss'] = totals['loss'] / seen
        logs[self.metric_name] = totals[self.metric_name] / seen

# %%
def create_nshot_task_label(k: int, q: int) -> torch.Tensor:
    """Creates an n-shot task label.

    Label has the structure:
        [0]*q + [1]*q + ... + [k-1]*q

    # TODO: Test this

    # Arguments
        k: Number of classes in the n-shot classification task
        q: Number of query samples for each class in the n-shot classification task

    # Returns
        y: Label vector for n-shot task of shape [q * k, ]
    """
    y = torch.arange(0, k, 1 / q).long()
    return y

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # few_shot.maml

# %%
#from few_shot.maml import meta_gradient_step
def replace_grad(parameter_gradients, parameter_name):
    def replace_grad_(module):
        return parameter_gradients[parameter_name]

    return replace_grad_
    
def meta_gradient_step(model: Module,
                       optimiser: Optimizer,
                       loss_fn: Callable,
                       x: torch.Tensor,
                       y: torch.Tensor,
                       n_shot: int,
                       k_way: int,
                       q_queries: int,
                       order: int,
                       inner_train_steps: int,
                       inner_lr: float,
                       train: bool,
                       device: Union[str, torch.device]):
    """
    Perform a gradient step on a meta-learner.

    # Arguments
        model: Base model of the meta-learner being trained
        optimiser: Optimiser to calculate gradient step from loss
        loss_fn: Loss function to calculate between predictions and outputs
        x: Input samples for all few shot tasks
        y: Input labels of all few shot tasks
        n_shot: Number of examples per class in the support set of each task
        k_way: Number of classes in the few shot classification task of each task
        q_queries: Number of examples per class in the query set of each task. The query set is used to calculate
            meta-gradients after applying the update to
        order: Whether to use 1st order MAML (update meta-learner weights with gradients of the updated weights on the
            query set) or 2nd order MAML (use 2nd order updates by differentiating through the gradients of the updated
            weights on the query with respect to the original weights).
        inner_train_steps: Number of gradient steps to fit the fast weights during each inner update
        inner_lr: Learning rate used to update the fast weights on the inner update
        train: Whether to update the meta-learner weights at the end of the episode.
        device: Device on which to run computation
    """
    data_shape = x.shape[2:]
    create_graph = (True if order == 2 else False) and train

    task_gradients = []
    task_losses = []
    task_predictions = []
    for meta_batch in x:
        # By construction x is a 5D tensor of shape: (meta_batch_size, n*k + q*k, channels, width, height)
        # Hence when we iterate over the first  dimension we are iterating through the meta batches
        x_task_train = meta_batch[:n_shot * k_way]
        x_task_val = meta_batch[n_shot * k_way:]

        # Create a fast model using the current meta model weights
        fast_weights = OrderedDict(model.named_parameters())

        # Train the model for `inner_train_steps` iterations
        for inner_batch in range(inner_train_steps):
            # Perform update of model weights
            y = create_nshot_task_label(k_way, n_shot).to(device)
            logits = model.functional_forward(x_task_train, fast_weights)
            loss = loss_fn(logits, y)
            gradients = torch.autograd.grad(loss, fast_weights.values(), create_graph=create_graph)

            # Update weights manually
            fast_weights = OrderedDict(
                (name, param - inner_lr * grad)
                for ((name, param), grad) in zip(fast_weights.items(), gradients)
            )

        # Do a pass of the model on the validation data from the current task
        y = create_nshot_task_label(k_way, q_queries).to(device)
        logits = model.functional_forward(x_task_val, fast_weights)
        loss = loss_fn(logits, y)
        loss.backward(retain_graph=True)

        # Get post-update accuracies
        y_pred = logits.softmax(dim=1)
        task_predictions.append(y_pred)

        # Accumulate losses and gradients
        task_losses.append(loss)
        gradients = torch.autograd.grad(loss, fast_weights.values(), create_graph=create_graph)
        named_grads = {name: g for ((name, _), g) in zip(fast_weights.items(), gradients)}
        task_gradients.append(named_grads)

    if order == 1:
        if train:
            sum_task_gradients = {k: torch.stack([grad[k] for grad in task_gradients]).mean(dim=0)
                                  for k in task_gradients[0].keys()}
            hooks = []
            for name, param in model.named_parameters():
                hooks.append(
                    param.register_hook(replace_grad(sum_task_gradients, name))
                )

            model.train()
            optimiser.zero_grad()
            # Dummy pass in order to create `loss` variable
            # Replace dummy gradients with mean task gradients using hooks
            logits = model(torch.zeros((k_way, ) + data_shape).to(device, dtype=torch.double))
            loss = loss_fn(logits, create_nshot_task_label(k_way, 1).to(device))
            loss.backward()
            optimiser.step()

            for h in hooks:
                h.remove()

        return torch.stack(task_losses).mean(), torch.cat(task_predictions)

    elif order == 2:
        model.train()
        optimiser.zero_grad()
        meta_batch_loss = torch.stack(task_losses).mean()

        if train:
            meta_batch_loss.backward()
            optimiser.step()

        return meta_batch_loss, torch.cat(task_predictions)
    else:
        raise ValueError('Order must be either 1 or 2.')

# %% [markdown]
# # few_shot.models

# %%
###Layers###
class Flatten(nn.Module):
    """Converts N-dimensional Tensor of shape [batch_size, d1, d2, ..., dn] to 2-dimensional Tensor
    of shape [batch_size, d1*d2*...*dn].

    # Arguments
        input: Input tensor
    """
    def forward(self, input):
        return input.view(input.size(0), -1)


class GlobalMaxPool1d(nn.Module):
    """Performs global max pooling over the entire length of a batched 1D tensor

    # Arguments
        input: Input tensor
    """
    def forward(self, input):
        return nn.functional.max_pool1d(input, kernel_size=input.size()[2:]).view(-1, input.size(1))


class GlobalAvgPool2d(nn.Module):
    """Performs global average pooling over the entire height and width of a batched 2D tensor

    # Arguments
        input: Input tensor
    """
    def forward(self, input):
        return nn.functional.avg_pool2d(input, kernel_size=input.size()[2:]).view(-1, input.size(1))

# %%
#from few_shot.models import FewShotClassifier
class FewShotClassifier(nn.Module):
    def __init__(self, num_input_channels: int, k_way: int, final_layer_size: int = 64):
        """Creates a few shot classifier as used in MAML.

        This network should be identical to the one created by `get_few_shot_encoder` but with a
        classification layer on top.

        # Arguments:
            num_input_channels: Number of color channels the model expects input data to contain. Omniglot = 1,
                miniImageNet = 3
            k_way: Number of classes the model will discriminate between
            final_layer_size: 64 for Omniglot, 1600 for miniImageNet
        """
        super(FewShotClassifier, self).__init__()
        self.conv1 = conv_block(num_input_channels, 64)
        self.conv2 = conv_block(64, 64)
        self.conv3 = conv_block(64, 64)
        self.conv4 = conv_block(64, 64)

        self.logits = nn.Linear(final_layer_size, k_way)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)

        x = x.view(x.size(0), -1)

        return self.logits(x)

    def functional_forward(self, x, weights):
        """Applies the same forward pass using PyTorch functional operators using a specified set of weights."""

        for block in [1, 2, 3, 4]:
            x = functional_conv_block(x, weights[f'conv{block}.0.weight'], weights[f'conv{block}.0.bias'],
                                      weights.get(f'conv{block}.1.weight'), weights.get(f'conv{block}.1.bias'))

        x = x.view(x.size(0), -1)

        x = F.linear(x, weights['logits.weight'], weights['logits.bias'])

        return x

# %%
def conv_block(in_channels: int, out_channels: int) -> nn.Module:
    """Returns a Module that performs 3x3 convolution, ReLu activation, 2x2 max pooling.

    # Arguments
        in_channels:
        out_channels:
    """
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2, stride=2)
    )

# %%
def functional_conv_block(x: torch.Tensor, weights: torch.Tensor, biases: torch.Tensor,
                          bn_weights, bn_biases) -> torch.Tensor:
    """Performs 3x3 convolution, ReLu activation, 2x2 max pooling in a functional fashion.

    # Arguments:
        x: Input Tensor for the conv block
        weights: Weights for the convolutional block
        biases: Biases for the convolutional block
        bn_weights:
        bn_biases:
    """
    x = F.conv2d(x, weights, biases, padding=1)
    x = F.batch_norm(x, running_mean=None, running_var=None, weight=bn_weights, bias=bn_biases, training=True)
    x = F.relu(x)
    x = F.max_pool2d(x, kernel_size=2, stride=2)
    return x

# %% [markdown]
# # few_shot.train

# %%
#from few_shot.callbacks import DefaultCallback, ProgressBarLogger, CallbackList, Callback
class CallbackList(object):
    """Container abstracting a list of callbacks.

    # Arguments
        callbacks: List of `Callback` instances.
    """
    def __init__(self, callbacks):
        self.callbacks = [c for c in callbacks]

    def set_params(self, params):
        for callback in self.callbacks:
            callback.set_params(params)

    def set_model(self, model):
        for callback in self.callbacks:
            callback.set_model(model)

    def on_epoch_begin(self, epoch, logs=None):
        """Called at the start of an epoch.
        # Arguments
            epoch: integer, index of epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_epoch_begin(epoch, logs)

    def on_epoch_end(self, epoch, logs=None):
        """Called at the end of an epoch.
        # Arguments
            epoch: integer, index of epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_epoch_end(epoch, logs)

    def on_batch_begin(self, batch, logs=None):
        """Called right before processing a batch.
        # Arguments
            batch: integer, index of batch within the current epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_batch_begin(batch, logs)

    def on_batch_end(self, batch, logs=None):
        """Called at the end of a batch.
        # Arguments
            batch: integer, index of batch within the current epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_batch_end(batch, logs)

    def on_train_begin(self, logs=None):
        """Called at the beginning of training.
        # Arguments
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_train_begin(logs)

    def on_train_end(self, logs=None):
        """Called at the end of training.
        # Arguments
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_train_end(logs)

# %%
class DefaultCallback(Callback):
    """Records metrics over epochs by averaging over each batch.

    NB The metrics are calculated with a moving model
    """
    def on_epoch_begin(self, batch, logs=None):
        self.seen = 0
        self.totals = {}
        self.metrics = ['loss'] + self.params['metrics']

    def on_batch_end(self, batch, logs=None):
        logs = logs or {}
        batch_size = logs.get('size', 1) or 1
        self.seen += batch_size

        for k, v in logs.items():
            if k in self.totals:
                self.totals[k] += v * batch_size
            else:
                self.totals[k] = v * batch_size

    def on_epoch_end(self, epoch, logs=None):
        if logs is not None:
            for k in self.metrics:
                if k in self.totals:
                    # Make value available to next callbacks.
                    logs[k] = self.totals[k] / self.seen

# %%
class ProgressBarLogger(Callback):
    """TQDM progress bar that displays the running average of loss and other metrics."""
    def __init__(self):
        super(ProgressBarLogger, self).__init__()

    def on_train_begin(self, logs=None):
        self.num_batches = self.params['num_batches']
        self.verbose = self.params['verbose']
        self.metrics = ['loss'] + self.params['metrics']

    def on_epoch_begin(self, epoch, logs=None):
        self.target = self.num_batches
        self.pbar = tqdm(total=self.target, desc='Epoch {}'.format(epoch))
        self.seen = 0

    def on_batch_begin(self, batch, logs=None):
        self.log_values = {}

    def on_batch_end(self, batch, logs=None):
        logs = logs or {}
        self.seen += 1

        for k in self.metrics:
            if k in logs:
                self.log_values[k] = logs[k]

        # Skip progbar update for the last batch;
        # will be handled by on_epoch_end.
        if self.verbose and self.seen < self.target:
            self.pbar.update(1)
            self.pbar.set_postfix(self.log_values)

    def on_epoch_end(self, epoch, logs=None):
        # Update log values
        self.log_values = {}
        for k in self.metrics:
            if k in logs:
                self.log_values[k] = logs[k]

        if self.verbose:
            self.pbar.update(1)
            self.pbar.set_postfix(self.log_values)

        self.pbar.close()

# %%
def gradient_step(model: Module, optimiser: Optimizer, loss_fn: Callable, x: torch.Tensor, y: torch.Tensor, **kwargs):
    """Takes a single gradient step.

    # Arguments
        model: Model to be fitted
        optimiser: Optimiser to calculate gradient step from loss
        loss_fn: Loss function to calculate between predictions and outputs
        x: Input samples
        y: Input targets
    """
    model.train()
    optimiser.zero_grad()
    y_pred = model(x)
    loss = loss_fn(y_pred, y)
    loss.backward()
    optimiser.step()

    return loss, y_pred

# %%
def batch_metrics(model: Module, y_pred: torch.Tensor, y: torch.Tensor, metrics: List[Union[str, Callable]],
                  batch_logs: dict):
    """Calculates metrics for the current training batch

    # Arguments
        model: Model being fit
        y_pred: predictions for a particular batch
        y: labels for a particular batch
        batch_logs: Dictionary of logs for the current batch
    """
    model.eval()
    for m in metrics:
        if isinstance(m, str):
            batch_logs[m] = NAMED_METRICS[m](y, y_pred)
        else:
            # Assume metric is a callable function
            batch_logs = m(y, y_pred)

    return batch_logs

# %%
def fit(model: Module, optimiser: Optimizer, loss_fn: Callable, epochs: int, dataloader: DataLoader,
        prepare_batch: Callable, metrics: List[Union[str, Callable]] = None, callbacks: List[Callback] = None,
        verbose: bool =True, fit_function: Callable = gradient_step, fit_function_kwargs: dict = {}):
    """Function to abstract away training loop.

    The benefit of this function is that allows training scripts to be much more readable and allows for easy re-use of
    common training functionality provided they are written as a subclass of voicemap.Callback (following the
    Keras API).

    # Arguments
        model: Model to be fitted.
        optimiser: Optimiser to calculate gradient step from loss
        loss_fn: Loss function to calculate between predictions and outputs
        epochs: Number of epochs of fitting to be performed
        dataloader: `torch.DataLoader` instance to fit the model to
        prepare_batch: Callable to perform any desired preprocessing
        metrics: Optional list of metrics to evaluate the model with
        callbacks: Additional functionality to incorporate into training such as logging metrics to csv, model
            checkpointing, learning rate scheduling etc... See voicemap.callbacks for more.
        verbose: All print output is muted if this argument is `False`
        fit_function: Function for calculating gradients. Leave as default for simple supervised training on labelled
            batches. For more complex training procedures (meta-learning etc...) you will need to write your own
            fit_function
        fit_function_kwargs: Keyword arguments to pass to `fit_function`
    """
    # Determine number of samples:
    num_batches = len(dataloader)
    batch_size = dataloader.batch_size

    callbacks = CallbackList([DefaultCallback(), ] + (callbacks or []) + [ProgressBarLogger(), ])
    callbacks.set_model(model)
    callbacks.set_params({
        'num_batches': num_batches,
        'batch_size': batch_size,
        'verbose': verbose,
        'metrics': (metrics or []),
        'prepare_batch': prepare_batch,
        'loss_fn': loss_fn,
        'optimiser': optimiser
    })

    if verbose:
        print('Begin training...')

    callbacks.on_train_begin()

    for epoch in range(1, epochs+1):
        callbacks.on_epoch_begin(epoch)

        epoch_logs = {}
        for batch_index, batch in enumerate(dataloader):
            batch_logs = dict(batch=batch_index, size=(batch_size or 1))

            callbacks.on_batch_begin(batch_index, batch_logs)

            x, y = prepare_batch(batch)

            loss, y_pred = fit_function(model, optimiser, loss_fn, x, y, **fit_function_kwargs)
            batch_logs['loss'] = loss.item()

            # Loops through all metrics
            batch_logs = batch_metrics(model, y_pred, y, metrics, batch_logs)

            callbacks.on_batch_end(batch_index, batch_logs)

        # Run on epoch end
        callbacks.on_epoch_end(epoch, epoch_logs)

    # Run on train end
    if verbose:
        print('Finished.')

    callbacks.on_train_end()

# %% [markdown]
# # few_shot.callbacks *

# %%
class LearningRateScheduler(Callback):
    """Learning rate scheduler.
    # Arguments
        schedule: a function that takes an epoch index as input
            (integer, indexed from 0) and current learning rate
            and returns a new learning rate as output (float).
        verbose: int. 0: quiet, 1: update messages.
    """

    def __init__(self, schedule, verbose=0):
        super(LearningRateScheduler, self).__init__()
        self.schedule = schedule
        self.verbose = verbose

    def on_train_begin(self, logs=None):
        self.optimiser = self.params['optimiser']

    def on_epoch_begin(self, epoch, logs=None):
        lrs = [self.schedule(epoch, param_group['lr']) for param_group in self.optimiser.param_groups]

        if not all(isinstance(lr, (float, np.float32, np.float64)) for lr in lrs):
            raise ValueError('The output of the "schedule" function '
                             'should be float.')
        self.set_lr(epoch, lrs)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        if len(self.optimiser.param_groups) == 1:
            logs['lr'] = self.optimiser.param_groups[0]['lr']
        else:
            for i, param_group in enumerate(self.optimiser.param_groups):
                logs['lr_{}'.format(i)] = param_group['lr']

    def set_lr(self, epoch, lrs):
        for i, param_group in enumerate(self.optimiser.param_groups):
            new_lr = lrs[i]
            param_group['lr'] = new_lr
            if self.verbose:
                print('Epoch {:5d}: setting learning rate'
                      ' of group {} to {:.4e}.'.format(epoch, i, new_lr))

# %%
class ModelCheckpoint(Callback):
    """Save the model after every epoch.

    `filepath` can contain named formatting options, which will be filled the value of `epoch` and keys in `logs`
    (passed in `on_epoch_end`).

    For example: if `filepath` is `weights.{epoch:02d}-{val_loss:.2f}.hdf5`, then the model checkpoints will be saved
    with the epoch number and the validation loss in the filename.

    # Arguments
        filepath: string, path to save the model file.
        monitor: quantity to monitor.
        verbose: verbosity mode, 0 or 1.
        save_best_only: if `save_best_only=True`,
            the latest best model according to
            the quantity monitored will not be overwritten.
        mode: one of {auto, min, max}.
            If `save_best_only=True`, the decision
            to overwrite the current save file is made
            based on either the maximization or the
            minimization of the monitored quantity. For `val_acc`,
            this should be `max`, for `val_loss` this should
            be `min`, etc. In `auto` mode, the direction is
            automatically inferred from the name of the monitored quantity.
        save_weights_only: if True, then only the model's weights will be
            saved (`model.save_weights(filepath)`), else the full model
            is saved (`model.save(filepath)`).
        period: Interval (number of epochs) between checkpoints.
    """

    def __init__(self, filepath, monitor='val_loss', verbose=0, save_best_only=False, mode='auto', period=1):
        super(ModelCheckpoint, self).__init__()
        self.monitor = monitor
        self.verbose = verbose
        self.filepath = filepath
        self.save_best_only = save_best_only
        self.period = period
        self.epochs_since_last_save = 0

        if mode not in ['auto', 'min', 'max']:
            raise ValueError('Mode must be one of (auto, min, max).')

        if mode == 'min':
            self.monitor_op = np.less
            self.best = np.Inf
        elif mode == 'max':
            self.monitor_op = np.greater
            self.best = -np.Inf
        else:
            if 'acc' in self.monitor or self.monitor.startswith('fmeasure'):
                self.monitor_op = np.greater
                self.best = -np.Inf
            else:
                self.monitor_op = np.less

        self.best = np.Inf

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        self.epochs_since_last_save += 1
        if self.epochs_since_last_save >= self.period:
            self.epochs_since_last_save = 0
            filepath = self.filepath.format(epoch=epoch + 1, **logs)
            if self.save_best_only:
                current = logs.get(self.monitor)
                if current is None:
                    warnings.warn('Can save best model only with %s available, '
                                  'skipping.' % (self.monitor), RuntimeWarning)
                else:
                    if self.monitor_op(current, self.best):
                        if self.verbose > 0:
                            print('\nEpoch %05d: %s improved from %0.5f to %0.5f,'
                                  ' saving model to %s'
                                  % (epoch + 1, self.monitor, self.best,
                                     current, filepath))
                        self.best = current
                        torch.save(self.model.state_dict(), filepath)
                    else:
                        if self.verbose > 0:
                            print('\nEpoch %05d: %s did not improve from %0.5f' %
                                  (epoch + 1, self.monitor, self.best))
            else:
                if self.verbose > 0:
                    print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
                torch.save(self.model.state_dict(), filepath)

# %%
class ReduceLROnPlateau(Callback):
    """Reduce learning rate when a metric has stopped improving.

    Models often benefit from reducing the learning rate by a factor
    of 2-10 once learning stagnates. This callback monitors a
    quantity and if no improvement is seen for a 'patience' number
    of epochs, the learning rate is reduced.

    # Arguments
        monitor: quantity to be monitored.
        factor: factor by which the learning rate will
            be reduced. new_lr = lr * factor
        patience: number of epochs with no improvement
            after which learning rate will be reduced.
        verbose: int. 0: quiet, 1: update messages.
        mode: one of {auto, min, max}. In `min` mode,
            lr will be reduced when the quantity
            monitored has stopped decreasing; in `max`
            mode it will be reduced when the quantity
            monitored has stopped increasing; in `auto`
            mode, the direction is automatically inferred
            from the name of the monitored quantity.
        min_delta: threshold for measuring the new optimum,
            to only focus on significant changes.
        cooldown: number of epochs to wait before resuming
            normal operation after lr has been reduced.
        min_lr: lower bound on the learning rate.
    """

    def __init__(self, monitor='val_loss', factor=0.1, patience=10,
                 verbose=0, mode='auto', min_delta=1e-4, cooldown=0, min_lr=0,
                 **kwargs):
        super(ReduceLROnPlateau, self).__init__()

        self.monitor = monitor
        if factor >= 1.0:
            raise ValueError('ReduceLROnPlateau does not support a factor >= 1.0.')
        self.factor = factor
        self.min_lr = min_lr
        self.min_delta = min_delta
        self.patience = patience
        self.verbose = verbose
        self.cooldown = cooldown
        self.cooldown_counter = 0  # Cooldown counter.
        self.wait = 0
        self.best = 0
        if mode not in ['auto', 'min', 'max']:
            raise ValueError('Mode must be one of (auto, min, max).')
        self.mode = mode
        self.monitor_op = None

        self._reset()

    def _reset(self):
        """Resets wait counter and cooldown counter.
        """
        if (self.mode == 'min' or
                (self.mode == 'auto' and 'acc' not in self.monitor)):
            self.monitor_op = lambda a, b: np.less(a, b - self.min_delta)
            self.best = np.Inf
        else:
            self.monitor_op = lambda a, b: np.greater(a, b + self.min_delta)
            self.best = -np.Inf
        self.cooldown_counter = 0
        self.wait = 0

    def on_train_begin(self, logs=None):
        self.optimiser = self.params['optimiser']
        self.min_lrs = [self.min_lr] * len(self.optimiser.param_groups)
        self._reset()

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        if len(self.optimiser.param_groups) == 1:
            logs['lr'] = self.optimiser.param_groups[0]['lr']
        else:
            for i, param_group in enumerate(self.optimiser.param_groups):
                logs['lr_{}'.format(i)] = param_group['lr']

        current = logs.get(self.monitor)

        if self.in_cooldown():
            self.cooldown_counter -= 1
            self.wait = 0

        if self.monitor_op(current, self.best):
            self.best = current
            self.wait = 0
        elif not self.in_cooldown():
            self.wait += 1
            if self.wait >= self.patience:
                self._reduce_lr(epoch)
                self.cooldown_counter = self.cooldown
                self.wait = 0

    def _reduce_lr(self, epoch):
        for i, param_group in enumerate(self.optimiser.param_groups):
            old_lr = float(param_group['lr'])
            new_lr = max(old_lr * self.factor, self.min_lrs[i])
            if old_lr - new_lr > self.min_delta:
                param_group['lr'] = new_lr
                if self.verbose:
                    print('Epoch {:5d}: reducing learning rate'
                          ' of group {} to {:.4e}.'.format(epoch, i, new_lr))

    def in_cooldown(self):
        return self.cooldown_counter > 0

# %%
class EvaluateMetrics(Callback):
    """Evaluates metrics on a dataset after every epoch.

    # Argments
        dataloader: torch.DataLoader of the dataset on which the model will be evaluated
        prefix: Prefix to prepend to the names of the metrics when they is logged. Defaults to 'val_' but can be changed
        if the model is to be evaluated on many datasets separately.
        suffix: Suffix to append to the names of the metrics when they is logged.
    """
    def __init__(self, dataloader, prefix='val_', suffix=''):
        super(EvaluateMetrics, self).__init__()
        self.dataloader = dataloader
        self.prefix = prefix
        self.suffix = suffix

    def on_train_begin(self, logs=None):
        self.metrics = self.params['metrics']
        self.prepare_batch = self.params['prepare_batch']
        self.loss_fn = self.params['loss_fn']

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs.update(
            evaluate(self.model, self.dataloader, self.prepare_batch, self.metrics, self.loss_fn, self.prefix, self.suffix)
        )

# %%
class CSVLogger(Callback):
    """Callback that streams epoch results to a csv file.
    Supports all values that can be represented as a string,
    including 1D iterables such as np.ndarray.

    # Arguments
        filename: filename of the csv file, e.g. 'run/log.csv'.
        separator: string used to separate elements in the csv file.
        append: True: append if file exists (useful for continuing
            training). False: overwrite existing file,
    """

    def __init__(self, filename, separator=',', append=False):
        self.sep = separator
        self.filename = filename
        self.append = append
        self.writer = None
        self.keys = None
        self.append_header = True
        self.file_flags = ''
        self._open_args = {'newline': '\n'}
        super(CSVLogger, self).__init__()

    def on_train_begin(self, logs=None):
        if self.append:
            if os.path.exists(self.filename):
                with open(self.filename, 'r' + self.file_flags) as f:
                    self.append_header = not bool(len(f.readline()))
            mode = 'a'
        else:
            mode = 'w'

        self.csv_file = io.open(self.filename,
                                mode + self.file_flags,
                                **self._open_args)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        def handle_value(k):
            is_zero_dim_ndarray = isinstance(k, np.ndarray) and k.ndim == 0
            if isinstance(k, str):
                return k
            elif isinstance(k, Iterable) and not is_zero_dim_ndarray:
                return '"[%s]"' % (', '.join(map(str, k)))
            else:
                return k

        if self.keys is None:
            self.keys = sorted(logs.keys())

        if not self.writer:
            class CustomDialect(csv.excel):
                delimiter = self.sep
            fieldnames = ['epoch'] + self.keys
            self.writer = csv.DictWriter(self.csv_file,
                                         fieldnames=fieldnames,
                                         dialect=CustomDialect)
            if self.append_header:
                self.writer.writeheader()

        row_dict = OrderedDict({'epoch': epoch})
        row_dict.update((key, handle_value(logs[key])) for key in self.keys)
        self.writer.writerow(row_dict)
        self.csv_file.flush()

    def on_train_end(self, logs=None):
        self.csv_file.close()
        self.writer = None

# %%
class ProgressBarLogger(Callback):
    """TQDM progress bar that displays the running average of loss and other metrics."""
    def __init__(self):
        super(ProgressBarLogger, self).__init__()

    def on_train_begin(self, logs=None):
        self.num_batches = self.params['num_batches']
        self.verbose = self.params['verbose']
        self.metrics = ['loss'] + self.params['metrics']

    def on_epoch_begin(self, epoch, logs=None):
        self.target = self.num_batches
        self.pbar = tqdm(total=self.target, desc='Epoch {}'.format(epoch))
        self.seen = 0

    def on_batch_begin(self, batch, logs=None):
        self.log_values = {}

    def on_batch_end(self, batch, logs=None):
        logs = logs or {}
        self.seen += 1

        for k in self.metrics:
            if k in logs:
                self.log_values[k] = logs[k]

        # Skip progbar update for the last batch;
        # will be handled by on_epoch_end.
        if self.verbose and self.seen < self.target:
            self.pbar.update(1)
            self.pbar.set_postfix(self.log_values)

    def on_epoch_end(self, epoch, logs=None):
        # Update log values
        self.log_values = {}
        for k in self.metrics:
            if k in logs:
                self.log_values[k] = logs[k]

        if self.verbose:
            self.pbar.update(1)
            self.pbar.set_postfix(self.log_values)

        self.pbar.close()

# %%
class DefaultCallback(Callback):
    """Records metrics over epochs by averaging over each batch.

    NB The metrics are calculated with a moving model
    """
    def on_epoch_begin(self, batch, logs=None):
        self.seen = 0
        self.totals = {}
        self.metrics = ['loss'] + self.params['metrics']

    def on_batch_end(self, batch, logs=None):
        logs = logs or {}
        batch_size = logs.get('size', 1) or 1
        self.seen += batch_size

        for k, v in logs.items():
            if k in self.totals:
                self.totals[k] += v * batch_size
            else:
                self.totals[k] = v * batch_size

    def on_epoch_end(self, epoch, logs=None):
        if logs is not None:
            for k in self.metrics:
                if k in self.totals:
                    # Make value available to next callbacks.
                    logs[k] = self.totals[k] / self.seen

# %%
class CallbackList(object):
    """Container abstracting a list of callbacks.

    # Arguments
        callbacks: List of `Callback` instances.
    """
    def __init__(self, callbacks):
        self.callbacks = [c for c in callbacks]

    def set_params(self, params):
        for callback in self.callbacks:
            callback.set_params(params)

    def set_model(self, model):
        for callback in self.callbacks:
            callback.set_model(model)

    def on_epoch_begin(self, epoch, logs=None):
        """Called at the start of an epoch.
        # Arguments
            epoch: integer, index of epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_epoch_begin(epoch, logs)

    def on_epoch_end(self, epoch, logs=None):
        """Called at the end of an epoch.
        # Arguments
            epoch: integer, index of epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_epoch_end(epoch, logs)

    def on_batch_begin(self, batch, logs=None):
        """Called right before processing a batch.
        # Arguments
            batch: integer, index of batch within the current epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_batch_begin(batch, logs)

    def on_batch_end(self, batch, logs=None):
        """Called at the end of a batch.
        # Arguments
            batch: integer, index of batch within the current epoch.
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_batch_end(batch, logs)

    def on_train_begin(self, logs=None):
        """Called at the beginning of training.
        # Arguments
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_train_begin(logs)

    def on_train_end(self, logs=None):
        """Called at the end of training.
        # Arguments
            logs: dictionary of logs.
        """
        logs = logs or {}
        for callback in self.callbacks:
            callback.on_train_end(logs)

# %% [markdown]
# # few_shot.utils

# %%
#from few_shot.utils import setup_dirs
def setup_dirs():
    """Creates directories for this project."""
    #shutil.rmtree(PATH + '/logs/')
    
    os.mkdir(PATH + '/logs/')
    os.mkdir(PATH + '/logs/proto_nets')
    os.mkdir(PATH + '/logs/matching_nets')
    os.mkdir(PATH + '/logs/maml')
    os.mkdir(PATH + '/logs/maml_aircraft')
    shutil.rmtree(PATH + '/models/')
    os.mkdir(PATH + '/models/')
    os.mkdir(PATH + '/models/proto_nets')
    os.mkdir(PATH + '/models/matching_nets')
    #shutil.rmtree(PATH + '/models/maml')
    os.mkdir(PATH + '/models/maml')
    os.mkdir(PATH + '/models/maml_aircraft')

# %% [markdown]
# # config.py

# %%
# %cd '/content/drive/My Drive/CLASSIFICATION/Few Shot'
# Out:
# /content/drive/My Drive/CLASSIFICATION/Few Shot

# %%
PATH = '/content/drive/My Drive/CLASSIFICATION/Few Shot'

DATA_PATH = '/content/drive/My Drive/CLASSIFICATION/Few Shot'

EPSILON = 1e-8

if DATA_PATH is None:
    raise Exception('Configure your data folder location in config.py before continuing!')

# %% [markdown]
# # maml_aircraft

# %%
setup_dirs()
#assert torch.cuda.is_available()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#torch.backends.cudnn.benchmark = True

# %%
dataset = 'aircrafts'
dataset_class = Aircraft
fc_layer_size = 1600
num_input_channels = 3

# %%
###################
# Create datasets #
###################
background = dataset_class('background')
background_taskloader = DataLoader(
    background,
    batch_sampler=NShotTaskSampler(background, 200, n=5, k=5, q=5,num_tasks=32),num_workers=8)
evaluation = dataset_class('evaluation')
evaluation_taskloader = DataLoader(
    evaluation,
    batch_sampler=NShotTaskSampler(evaluation, 20, n=5, k=5, q=5,num_tasks=32),num_workers=8)
# Out:
# Indexing background...
# 8000it [00:00, 59355.28it/s]
# Indexing evaluation...
# 2000it [00:00, 52183.54it/s]

# %%
param_str = f'{dataset}_order={1}_n={5}_k={5}_metabatch={32}_' \
            f'train_steps={5}_val_steps={10}'
print(param_str)
# Out:
# aircrafts_order=1_n=5_k=5_metabatch=32_train_steps=5_val_steps=10

# %%
############
# Training #
############
print(f'Training MAML on {dataset}...')
meta_model = FewShotClassifier(num_input_channels, 5, fc_layer_size).to(device, dtype=torch.double)
meta_optimiser = torch.optim.Adam(meta_model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss().to(device)


def prepare_meta_batch(n, k, q, meta_batch_size):
    def prepare_meta_batch_(batch):
        x, y = batch
        # Reshape to `meta_batch_size` number of tasks. Each task contains
        # n*k support samples to train the fast model on and q*k query samples to
        # evaluate the fast model on and generate meta-gradients
        x = x.reshape(meta_batch_size, n*k + q*k, num_input_channels, x.shape[-2], x.shape[-1])
        # Move to device
        x = x.double().to(device)
        # Create label
        y = create_nshot_task_label(k, q).to(device).repeat(meta_batch_size)
        return x, y

    return prepare_meta_batch_


callbacks = [
    EvaluateFewShot(
        eval_fn=meta_gradient_step,
        num_tasks=20,
        n_shot=5,
        k_way=5,
        q_queries=5,
        taskloader=evaluation_taskloader,
        prepare_batch=prepare_meta_batch(5, 5, 5, 32),
        # MAML kwargs
        inner_train_steps=10,
        inner_lr=0.01,
        device=device,
        order=1,
    ),
    ModelCheckpoint(
        filepath=PATH + f'/models/maml_aircraft/{param_str}.pth',
        monitor=f'val_{5}-shot_{5}-way_acc'
    ),
    ReduceLROnPlateau(patience=10, factor=0.5, monitor=f'val_loss'),
    CSVLogger(PATH + f'/logs/maml_aircraft/{param_str}.csv'),
]


fit(
    meta_model,
    meta_optimiser,
    loss_fn,
    epochs=10,
    dataloader=background_taskloader,
    prepare_batch=prepare_meta_batch(5, 5, 5, 32),
    callbacks=callbacks,
    metrics=['categorical_accuracy'],
    fit_function=meta_gradient_step,
    fit_function_kwargs={'n_shot': 5, 'k_way': 5, 'q_queries': 5,
                         'train': True,
                         'order': 1, 'device': device, 'inner_train_steps': 5,
                         'inner_lr': 0.01},
)
# Out:
# Epoch 1:   0%|          | 0/200 [00:00<?, ?it/s]
# Training MAML on aircrafts...
# Begin training...
# Streaming output truncated to the last 5000 lines.
# Epoch 6:  85%|████████▌ | 170/200 [38:58<08:24, 16.81s/it, loss=0.715, categorical_accuracy=0.741]
#
#
# Epoch 6:  85%|████████▌ | 170/200 [38:58<08:24, 16.81s/it, loss=0.643, categorical_accuracy=0.775]
#
#
# Epoch 6:  86%|████████▌ | 171/200 [39:06<06:53, 14.24s/it, loss=0.643, categorical_accuracy=0.775]
#
#
# Epoch 6:  86%|████████▌ | 171/200 [39:06<06:53, 14.24s/it, loss=0.586, categorical_accuracy=0.804]
#
#
# Epoch 6:  86%|████████▌ | 172/200 [39:14<05:47, 12.42s/it, loss=0.586, categorical_accuracy=0.804]
#
#
# Epoch 6:  86%|████████▌ | 172/200 [39:14<05:47, 12.42s/it, loss=0.676, categorical_accuracy=0.738]
#
#
# Epoch 6:  86%|████████▋ | 173/200 [39:22<04:59, 11.10s/it, loss=0.676, categorical_accuracy=0.738]
#
#
# Epoch 6:  86%|████████▋ | 173/200 [39:22<04:59, 11.10s/it, loss=0.727, categorical_accuracy=0.74]
#
#
# Epoch 6:  87%|████████▋ | 174/200 [39:30<04:26, 10.24s/it, loss=0.727, categorical_accuracy=0.74]
#
#
# Epoch 6:  87%|████████▋ | 174/200 [39:30<04:26, 10.24s/it, loss=0.674, categorical_accuracy=0.785]
#
#
# Epoch 6:  88%|████████▊ | 175/200 [39:39<04:00,  9.62s/it, loss=0.674, categorical_accuracy=0.785]
#
#
# Epoch 6:  88%|████████▊ | 175/200 [39:39<04:00,  9.62s/it, loss=0.611, categorical_accuracy=0.785]
#
#
# Epoch 6:  88%|████████▊ | 176/200 [39:47<03:41,  9.23s/it, loss=0.611, categorical_accuracy=0.785]
#
#
# Epoch 6:  88%|████████▊ | 176/200 [39:47<03:41,  9.23s/it, loss=0.605, categorical_accuracy=0.791]
#
#
# Epoch 6:  88%|████████▊ | 177/200 [40:37<08:16, 21.57s/it, loss=0.605, categorical_accuracy=0.791]
#
#
# Epoch 6:  88%|████████▊ | 177/200 [40:37<08:16, 21.57s/it, loss=0.576, categorical_accuracy=0.8]
#
#
# Epoch 6:  89%|████████▉ | 178/200 [40:45<06:25, 17.53s/it, loss=0.576, categorical_accuracy=0.8]
#
#
# Epoch 6:  89%|████████▉ | 178/200 [40:45<06:25, 17.53s/it, loss=0.65, categorical_accuracy=0.794]
#
#
# Epoch 6:  90%|████████▉ | 179/200 [40:54<05:12, 14.87s/it, loss=0.65, categorical_accuracy=0.794]
#
#
# Epoch 6:  90%|████████▉ | 179/200 [40:54<05:12, 14.87s/it, loss=0.671, categorical_accuracy=0.75]
#
#
# Epoch 6:  90%|█████████ | 180/200 [41:02<04:18, 12.93s/it, loss=0.671, categorical_accuracy=0.75]
#
#
# Epoch 6:  90%|█████████ | 180/200 [41:02<04:18, 12.93s/it, loss=0.578, categorical_accuracy=0.79]
#
#
# Epoch 6:  90%|█████████ | 181/200 [41:10<03:38, 11.48s/it, loss=0.578, categorical_accuracy=0.79]
#
#
# Epoch 6:  90%|█████████ | 181/200 [41:10<03:38, 11.48s/it, loss=0.548, categorical_accuracy=0.811]
#
#
# Epoch 6:  91%|█████████ | 182/200 [41:19<03:11, 10.62s/it, loss=0.548, categorical_accuracy=0.811]
#
#
# Epoch 6:  91%|█████████ | 182/200 [41:19<03:11, 10.62s/it, loss=0.592, categorical_accuracy=0.776]
#
#
# Epoch 6:  92%|█████████▏| 183/200 [41:28<02:49,  9.99s/it, loss=0.592, categorical_accuracy=0.776]
#
#
# Epoch 6:  92%|█████████▏| 183/200 [41:28<02:49,  9.99s/it, loss=0.689, categorical_accuracy=0.744]
#
#
# Epoch 6:  92%|█████████▏| 184/200 [41:35<02:27,  9.22s/it, loss=0.689, categorical_accuracy=0.744]
#
#
# Epoch 6:  92%|█████████▏| 184/200 [41:35<02:27,  9.22s/it, loss=0.606, categorical_accuracy=0.774]
#
#
# Epoch 6:  92%|█████████▎| 185/200 [42:19<04:56, 19.78s/it, loss=0.606, categorical_accuracy=0.774]
#
#
# Epoch 6:  92%|█████████▎| 185/200 [42:19<04:56, 19.78s/it, loss=0.59, categorical_accuracy=0.796]
#
#
# Epoch 6:  93%|█████████▎| 186/200 [42:25<03:36, 15.44s/it, loss=0.59, categorical_accuracy=0.796]
#
#
# Epoch 6:  93%|█████████▎| 186/200 [42:25<03:36, 15.44s/it, loss=0.659, categorical_accuracy=0.774]
#
#
# Epoch 6:  94%|█████████▎| 187/200 [42:30<02:39, 12.28s/it, loss=0.659, categorical_accuracy=0.774]
#
#
# Epoch 6:  94%|█████████▎| 187/200 [42:30<02:39, 12.28s/it, loss=0.66, categorical_accuracy=0.772]
#
#
# Epoch 6:  94%|█████████▍| 188/200 [42:35<02:01, 10.10s/it, loss=0.66, categorical_accuracy=0.772]
#
#
# Epoch 6:  94%|█████████▍| 188/200 [42:35<02:01, 10.10s/it, loss=0.6, categorical_accuracy=0.781]
#
#
# Epoch 6:  94%|█████████▍| 189/200 [42:40<01:33,  8.54s/it, loss=0.6, categorical_accuracy=0.781]
#
#
# Epoch 6:  94%|█████████▍| 189/200 [42:40<01:33,  8.54s/it, loss=0.632, categorical_accuracy=0.771]
#
#
# Epoch 6:  95%|█████████▌| 190/200 [42:44<01:14,  7.41s/it, loss=0.632, categorical_accuracy=0.771]
#
#
# Epoch 6:  95%|█████████▌| 190/200 [42:44<01:14,  7.41s/it, loss=0.517, categorical_accuracy=0.826]
#
#
# Epoch 6:  96%|█████████▌| 191/200 [42:49<00:59,  6.65s/it, loss=0.517, categorical_accuracy=0.826]
#
#
# Epoch 6:  96%|█████████▌| 191/200 [42:49<00:59,  6.65s/it, loss=0.584, categorical_accuracy=0.806]
#
#
# Epoch 6:  96%|█████████▌| 192/200 [42:54<00:49,  6.16s/it, loss=0.584, categorical_accuracy=0.806]
#
#
# Epoch 6:  96%|█████████▌| 192/200 [42:54<00:49,  6.16s/it, loss=0.61, categorical_accuracy=0.776]
#
#
# Epoch 6:  96%|█████████▋| 193/200 [43:59<02:46, 23.85s/it, loss=0.61, categorical_accuracy=0.776]
#
#
# Epoch 6:  96%|█████████▋| 193/200 [43:59<02:46, 23.85s/it, loss=0.559, categorical_accuracy=0.816]
#
#
# Epoch 6:  97%|█████████▋| 194/200 [44:03<01:46, 17.82s/it, loss=0.559, categorical_accuracy=0.816]
#
#
# Epoch 6:  97%|█████████▋| 194/200 [44:03<01:46, 17.82s/it, loss=0.724, categorical_accuracy=0.738]
#
#
# Epoch 6:  98%|█████████▊| 195/200 [44:07<01:07, 13.60s/it, loss=0.724, categorical_accuracy=0.738]
#
#
# Epoch 6:  98%|█████████▊| 195/200 [44:07<01:07, 13.60s/it, loss=0.601, categorical_accuracy=0.791]
#
#
# Epoch 6:  98%|█████████▊| 196/200 [44:11<00:42, 10.64s/it, loss=0.601, categorical_accuracy=0.791]
#
#
# Epoch 6:  98%|█████████▊| 196/200 [44:11<00:42, 10.64s/it, loss=0.628, categorical_accuracy=0.78]
#
#
# Epoch 6:  98%|█████████▊| 197/200 [44:14<00:25,  8.57s/it, loss=0.628, categorical_accuracy=0.78]
#
#
# Epoch 6:  98%|█████████▊| 197/200 [44:14<00:25,  8.57s/it, loss=0.663, categorical_accuracy=0.77]
#
#
# Epoch 6:  99%|█████████▉| 198/200 [44:18<00:14,  7.12s/it, loss=0.663, categorical_accuracy=0.77]
#
#
# Epoch 6:  99%|█████████▉| 198/200 [44:18<00:14,  7.12s/it, loss=0.613, categorical_accuracy=0.771]
#
#
# Epoch 6: 100%|█████████▉| 199/200 [44:22<00:06,  6.11s/it, loss=0.613, categorical_accuracy=0.771]
#
#
# Epoch 6: 100%|█████████▉| 199/200 [44:22<00:06,  6.11s/it, loss=0.567, categorical_accuracy=0.801]
#
#
# Epoch 6: 100%|██████████| 200/200 [49:28<00:00, 96.04s/it, loss=0.567, categorical_accuracy=0.801]
#
#
# Epoch 6: 100%|██████████| 200/200 [49:28<00:00, 14.84s/it, loss=0.651, categorical_accuracy=0.77]
#
#
#
# Epoch 7:   0%|          | 0/200 [00:00<?, ?it/s]
#
#
# Epoch 7:   0%|          | 1/200 [01:47<5:55:46, 107.27s/it]
#
#
# Epoch 7:   0%|          | 1/200 [01:47<5:55:46, 107.27s/it, loss=0.618, categorical_accuracy=0.791]
#
#
# Epoch 7:   1%|          | 2/200 [01:55<4:15:43, 77.49s/it, loss=0.618, categorical_accuracy=0.791]
#
#
# Epoch 7:   1%|          | 2/200 [01:55<4:15:43, 77.49s/it, loss=0.673, categorical_accuracy=0.775]
#
#
# Epoch 7:   2%|▏         | 3/200 [02:03<3:06:09, 56.70s/it, loss=0.673, categorical_accuracy=0.775]
#
#
# Epoch 7:   2%|▏         | 3/200 [02:03<3:06:09, 56.70s/it, loss=0.608, categorical_accuracy=0.779]
#
#
# Epoch 7:   2%|▏         | 4/200 [02:11<2:17:39, 42.14s/it, loss=0.608, categorical_accuracy=0.779]
#
#
# Epoch 7:   2%|▏         | 4/200 [02:11<2:17:39, 42.14s/it, loss=0.638, categorical_accuracy=0.76]
#
#
# Epoch 7:   2%|▎         | 5/200 [02:19<1:43:57, 31.99s/it, loss=0.638, categorical_accuracy=0.76]
#
#
# Epoch 7:   2%|▎         | 5/200 [02:19<1:43:57, 31.99s/it, loss=0.594, categorical_accuracy=0.79]
#
#
# Epoch 7:   3%|▎         | 6/200 [02:28<1:20:35, 24.92s/it, loss=0.594, categorical_accuracy=0.79]
#
#
# Epoch 7:   3%|▎         | 6/200 [02:28<1:20:35, 24.92s/it, loss=0.614, categorical_accuracy=0.785]
#
#
# Epoch 7:   4%|▎         | 7/200 [02:36<1:04:09, 19.94s/it, loss=0.614, categorical_accuracy=0.785]
#
#
# Epoch 7:   4%|▎         | 7/200 [02:36<1:04:09, 19.94s/it, loss=0.57, categorical_accuracy=0.797]
#
#
# Epoch 7:   4%|▍         | 8/200 [02:45<52:38, 16.45s/it, loss=0.57, categorical_accuracy=0.797]
#
#
# Epoch 7:   4%|▍         | 8/200 [02:45<52:38, 16.45s/it, loss=0.571, categorical_accuracy=0.799]
#
#
# Epoch 7:   4%|▍         | 9/200 [03:31<1:20:42, 25.35s/it, loss=0.571, categorical_accuracy=0.799]
#
#
# Epoch 7:   4%|▍         | 9/200 [03:31<1:20:42, 25.35s/it, loss=0.624, categorical_accuracy=0.772]
#
#
# Epoch 7:   5%|▌         | 10/200 [03:39<1:04:16, 20.30s/it, loss=0.624, categorical_accuracy=0.772]
#
#
# Epoch 7:   5%|▌         | 10/200 [03:39<1:04:16, 20.30s/it, loss=0.703, categorical_accuracy=0.756]
#
#
# Epoch 7:   6%|▌         | 11/200 [03:48<52:59, 16.82s/it, loss=0.703, categorical_accuracy=0.756]
#
#
# Epoch 7:   6%|▌         | 11/200 [03:48<52:59, 16.82s/it, loss=0.588, categorical_accuracy=0.776]
#
#
# Epoch 7:   6%|▌         | 12/200 [03:56<44:26, 14.18s/it, loss=0.588, categorical_accuracy=0.776]
#
#
# Epoch 7:   6%|▌         | 12/200 [03:56<44:26, 14.18s/it, loss=0.622, categorical_accuracy=0.775]
#
#
# Epoch 7:   6%|▋         | 13/200 [04:04<38:40, 12.41s/it, loss=0.622, categorical_accuracy=0.775]
#
#
# Epoch 7:   6%|▋         | 13/200 [04:04<38:40, 12.41s/it, loss=0.673, categorical_accuracy=0.767]
#
#
# Epoch 7:   7%|▋         | 14/200 [04:12<34:02, 10.98s/it, loss=0.673, categorical_accuracy=0.767]
#
#
# Epoch 7:   7%|▋         | 14/200 [04:12<34:02, 10.98s/it, loss=0.645, categorical_accuracy=0.769]
#
#
# Epoch 7:   8%|▊         | 15/200 [04:20<31:39, 10.27s/it, loss=0.645, categorical_accuracy=0.769]
#
#
# Epoch 7:   8%|▊         | 15/200 [04:20<31:39, 10.27s/it, loss=0.645, categorical_accuracy=0.756]
#
#
# Epoch 7:   8%|▊         | 16/200 [04:28<29:12,  9.53s/it, loss=0.645, categorical_accuracy=0.756]
#
#
# Epoch 7:   8%|▊         | 16/200 [04:28<29:12,  9.53s/it, loss=0.621, categorical_accuracy=0.787]
#
#
# Epoch 7:   8%|▊         | 17/200 [05:15<1:03:10, 20.71s/it, loss=0.621, categorical_accuracy=0.787]
#
#
# Epoch 7:   8%|▊         | 17/200 [05:15<1:03:10, 20.71s/it, loss=0.57, categorical_accuracy=0.815]
#
#
# Epoch 7:   9%|▉         | 18/200 [05:23<51:20, 16.92s/it, loss=0.57, categorical_accuracy=0.815]
#
#
# Epoch 7:   9%|▉         | 18/200 [05:23<51:20, 16.92s/it, loss=0.589, categorical_accuracy=0.781]
#
#
# Epoch 7:  10%|▉         | 19/200 [05:31<42:47, 14.19s/it, loss=0.589, categorical_accuracy=0.781]
#
#
# Epoch 7:  10%|▉         | 19/200 [05:31<42:47, 14.19s/it, loss=0.638, categorical_accuracy=0.764]
#
#
# Epoch 7:  10%|█         | 20/200 [05:39<37:18, 12.44s/it, loss=0.638, categorical_accuracy=0.764]
#
#
# Epoch 7:  10%|█         | 20/200 [05:39<37:18, 12.44s/it, loss=0.627, categorical_accuracy=0.79]
#
#
# Epoch 7:  10%|█         | 21/200 [05:48<33:29, 11.22s/it, loss=0.627, categorical_accuracy=0.79]
#
#
# Epoch 7:  10%|█         | 21/200 [05:48<33:29, 11.22s/it, loss=0.65, categorical_accuracy=0.767]
#
#
# Epoch 7:  11%|█         | 22/200 [05:56<30:34, 10.31s/it, loss=0.65, categorical_accuracy=0.767]
#
#
# Epoch 7:  11%|█         | 22/200 [05:56<30:34, 10.31s/it, loss=0.716, categorical_accuracy=0.754]
#
#
# Epoch 7:  12%|█▏        | 23/200 [06:03<27:54,  9.46s/it, loss=0.716, categorical_accuracy=0.754]
#
#
# Epoch 7:  12%|█▏        | 23/200 [06:03<27:54,  9.46s/it, loss=0.645, categorical_accuracy=0.776]
#
#
# Epoch 7:  12%|█▏        | 24/200 [06:11<26:24,  9.01s/it, loss=0.645, categorical_accuracy=0.776]
#
#
# Epoch 7:  12%|█▏        | 24/200 [06:11<26:24,  9.01s/it, loss=0.654, categorical_accuracy=0.769]
#
#
# Epoch 7:  12%|█▎        | 25/200 [07:01<1:02:10, 21.32s/it, loss=0.654, categorical_accuracy=0.769]
#
#
# Epoch 7:  12%|█▎        | 25/200 [07:01<1:02:10, 21.32s/it, loss=0.613, categorical_accuracy=0.78]
#
#
# Epoch 7:  13%|█▎        | 26/200 [07:09<50:17, 17.34s/it, loss=0.613, categorical_accuracy=0.78]
#
#
# Epoch 7:  13%|█▎        | 26/200 [07:09<50:17, 17.34s/it, loss=0.617, categorical_accuracy=0.776]
#
#
# Epoch 7:  14%|█▎        | 27/200 [07:18<42:04, 14.60s/it, loss=0.617, categorical_accuracy=0.776]
#
#
# Epoch 7:  14%|█▎        | 27/200 [07:18<42:04, 14.60s/it, loss=0.664, categorical_accuracy=0.757]
#
#
# Epoch 7:  14%|█▍        | 28/200 [07:25<36:00, 12.56s/it, loss=0.664, categorical_accuracy=0.757]
#
#
# Epoch 7:  14%|█▍        | 28/200 [07:25<36:00, 12.56s/it, loss=0.576, categorical_accuracy=0.807]
#
#
# Epoch 7:  14%|█▍        | 29/200 [07:34<32:06, 11.27s/it, loss=0.576, categorical_accuracy=0.807]
#
#
# Epoch 7:  14%|█▍        | 29/200 [07:34<32:06, 11.27s/it, loss=0.623, categorical_accuracy=0.796]
#
#
# Epoch 7:  15%|█▌        | 30/200 [07:41<28:58, 10.22s/it, loss=0.623, categorical_accuracy=0.796]
#
#
# Epoch 7:  15%|█▌        | 30/200 [07:41<28:58, 10.22s/it, loss=0.594, categorical_accuracy=0.797]
#
#
# Epoch 7:  16%|█▌        | 31/200 [07:50<27:47,  9.86s/it, loss=0.594, categorical_accuracy=0.797]
#
#
# Epoch 7:  16%|█▌        | 31/200 [07:50<27:47,  9.86s/it, loss=0.611, categorical_accuracy=0.792]
#
#
# Epoch 7:  16%|█▌        | 32/200 [07:59<26:25,  9.43s/it, loss=0.611, categorical_accuracy=0.792]
#
#
# Epoch 7:  16%|█▌        | 32/200 [07:59<26:25,  9.43s/it, loss=0.629, categorical_accuracy=0.769]
#
#
# Epoch 7:  16%|█▋        | 33/200 [08:46<57:47, 20.77s/it, loss=0.629, categorical_accuracy=0.769]
#
#
# Epoch 7:  16%|█▋        | 33/200 [08:46<57:47, 20.77s/it, loss=0.543, categorical_accuracy=0.824]
#
#
# Epoch 7:  17%|█▋        | 34/200 [08:54<46:30, 16.81s/it, loss=0.543, categorical_accuracy=0.824]
#
#
# Epoch 7:  17%|█▋        | 34/200 [08:54<46:30, 16.81s/it, loss=0.567, categorical_accuracy=0.8]
#
#
# Epoch 7:  18%|█▊        | 35/200 [09:02<39:05, 14.22s/it, loss=0.567, categorical_accuracy=0.8]
#
#
# Epoch 7:  18%|█▊        | 35/200 [09:02<39:05, 14.22s/it, loss=0.607, categorical_accuracy=0.779]
#
#
# Epoch 7:  18%|█▊        | 36/200 [09:10<34:13, 12.52s/it, loss=0.607, categorical_accuracy=0.779]
#
#
# Epoch 7:  18%|█▊        | 36/200 [09:10<34:13, 12.52s/it, loss=0.627, categorical_accuracy=0.782]
#
#
# Epoch 7:  18%|█▊        | 37/200 [09:18<30:18, 11.16s/it, loss=0.627, categorical_accuracy=0.782]
#
#
# Epoch 7:  18%|█▊        | 37/200 [09:18<30:18, 11.16s/it, loss=0.574, categorical_accuracy=0.795]
#
#
# Epoch 7:  19%|█▉        | 38/200 [09:26<27:24, 10.15s/it, loss=0.574, categorical_accuracy=0.795]
#
#
# Epoch 7:  19%|█▉        | 38/200 [09:26<27:24, 10.15s/it, loss=0.645, categorical_accuracy=0.759]
#
#
# Epoch 7:  20%|█▉        | 39/200 [09:34<25:45,  9.60s/it, loss=0.645, categorical_accuracy=0.759]
#
#
# Epoch 7:  20%|█▉        | 39/200 [09:34<25:45,  9.60s/it, loss=0.722, categorical_accuracy=0.73]
#
#
# Epoch 7:  20%|██        | 40/200 [09:43<24:29,  9.18s/it, loss=0.722, categorical_accuracy=0.73]
#
#
# Epoch 7:  20%|██        | 40/200 [09:43<24:29,  9.18s/it, loss=0.652, categorical_accuracy=0.754]
#
#
# Epoch 7:  20%|██        | 41/200 [10:33<57:22, 21.65s/it, loss=0.652, categorical_accuracy=0.754]
#
#
# Epoch 7:  20%|██        | 41/200 [10:33<57:22, 21.65s/it, loss=0.572, categorical_accuracy=0.814]
#
#
# Epoch 7:  21%|██        | 42/200 [10:41<46:16, 17.57s/it, loss=0.572, categorical_accuracy=0.814]
#
#
# Epoch 7:  21%|██        | 42/200 [10:41<46:16, 17.57s/it, loss=0.646, categorical_accuracy=0.765]
#
#
# Epoch 7:  22%|██▏       | 43/200 [10:50<38:54, 14.87s/it, loss=0.646, categorical_accuracy=0.765]
#
#
# Epoch 7:  22%|██▏       | 43/200 [10:50<38:54, 14.87s/it, loss=0.695, categorical_accuracy=0.736]
#
#
# Epoch 7:  22%|██▏       | 44/200 [10:58<33:20, 12.82s/it, loss=0.695, categorical_accuracy=0.736]
#
#
# Epoch 7:  22%|██▏       | 44/200 [10:58<33:20, 12.82s/it, loss=0.706, categorical_accuracy=0.744]
#
#
# Epoch 7:  22%|██▎       | 45/200 [11:07<30:07, 11.66s/it, loss=0.706, categorical_accuracy=0.744]
#
#
# Epoch 7:  22%|██▎       | 45/200 [11:07<30:07, 11.66s/it, loss=0.58, categorical_accuracy=0.809]
#
#
# Epoch 7:  23%|██▎       | 46/200 [11:15<27:17, 10.63s/it, loss=0.58, categorical_accuracy=0.809]
#
#
# Epoch 7:  23%|██▎       | 46/200 [11:15<27:17, 10.63s/it, loss=0.567, categorical_accuracy=0.79]
#
#
# Epoch 7:  24%|██▎       | 47/200 [11:24<25:20,  9.94s/it, loss=0.567, categorical_accuracy=0.79]
#
#
# Epoch 7:  24%|██▎       | 47/200 [11:24<25:20,  9.94s/it, loss=0.619, categorical_accuracy=0.785]
#
#
# Epoch 7:  24%|██▍       | 48/200 [11:31<23:17,  9.19s/it, loss=0.619, categorical_accuracy=0.785]
#
#
# Epoch 7:  24%|██▍       | 48/200 [11:31<23:17,  9.19s/it, loss=0.564, categorical_accuracy=0.8]
#
#
# Epoch 7:  24%|██▍       | 49/200 [12:18<51:30, 20.47s/it, loss=0.564, categorical_accuracy=0.8]
#
#
# Epoch 7:  24%|██▍       | 49/200 [12:18<51:30, 20.47s/it, loss=0.653, categorical_accuracy=0.764]
#
#
# Epoch 7:  25%|██▌       | 50/200 [12:26<41:59, 16.80s/it, loss=0.653, categorical_accuracy=0.764]
#
#
# Epoch 7:  25%|██▌       | 50/200 [12:26<41:59, 16.80s/it, loss=0.662, categorical_accuracy=0.75]
#
#
# Epoch 7:  26%|██▌       | 51/200 [12:34<35:27, 14.28s/it, loss=0.662, categorical_accuracy=0.75]
#
#
# Epoch 7:  26%|██▌       | 51/200 [12:34<35:27, 14.28s/it, loss=0.673, categorical_accuracy=0.762]
#
#
# Epoch 7:  26%|██▌       | 52/200 [12:43<30:44, 12.46s/it, loss=0.673, categorical_accuracy=0.762]
#
#
# Epoch 7:  26%|██▌       | 52/200 [12:43<30:44, 12.46s/it, loss=0.568, categorical_accuracy=0.786]
#
#
# Epoch 7:  26%|██▋       | 53/200 [12:51<27:24, 11.19s/it, loss=0.568, categorical_accuracy=0.786]
#
#
# Epoch 7:  26%|██▋       | 53/200 [12:51<27:24, 11.19s/it, loss=0.514, categorical_accuracy=0.801]
#
#
# Epoch 7:  27%|██▋       | 54/200 [12:59<25:07, 10.33s/it, loss=0.514, categorical_accuracy=0.801]
#
#
# Epoch 7:  27%|██▋       | 54/200 [12:59<25:07, 10.33s/it, loss=0.586, categorical_accuracy=0.78]
#
#
# Epoch 7:  28%|██▊       | 55/200 [13:08<23:38,  9.78s/it, loss=0.586, categorical_accuracy=0.78]
#
#
# Epoch 7:  28%|██▊       | 55/200 [13:08<23:38,  9.78s/it, loss=0.569, categorical_accuracy=0.802]
#
#
# Epoch 7:  28%|██▊       | 56/200 [13:16<22:15,  9.27s/it, loss=0.569, categorical_accuracy=0.802]
#
#
# Epoch 7:  28%|██▊       | 56/200 [13:16<22:15,  9.27s/it, loss=0.646, categorical_accuracy=0.782]
#
#
# Epoch 7:  28%|██▊       | 57/200 [14:05<50:48, 21.32s/it, loss=0.646, categorical_accuracy=0.782]
#
#
# Epoch 7:  28%|██▊       | 57/200 [14:05<50:48, 21.32s/it, loss=0.605, categorical_accuracy=0.779]
#
#
# Epoch 7:  29%|██▉       | 58/200 [14:14<41:16, 17.44s/it, loss=0.605, categorical_accuracy=0.779]
#
#
# Epoch 7:  29%|██▉       | 58/200 [14:14<41:16, 17.44s/it, loss=0.557, categorical_accuracy=0.809]
#
#
# Epoch 7:  30%|██▉       | 59/200 [14:22<34:24, 14.64s/it, loss=0.557, categorical_accuracy=0.809]
#
#
# Epoch 7:  30%|██▉       | 59/200 [14:22<34:24, 14.64s/it, loss=0.701, categorical_accuracy=0.748]
#
#
# Epoch 7:  30%|███       | 60/200 [14:30<29:22, 12.59s/it, loss=0.701, categorical_accuracy=0.748]
#
#
# Epoch 7:  30%|███       | 60/200 [14:30<29:22, 12.59s/it, loss=0.678, categorical_accuracy=0.782]
#
#
# Epoch 7:  30%|███       | 61/200 [14:38<25:59, 11.22s/it, loss=0.678, categorical_accuracy=0.782]
#
#
# Epoch 7:  30%|███       | 61/200 [14:38<25:59, 11.22s/it, loss=0.679, categorical_accuracy=0.765]
#
#
# Epoch 7:  31%|███       | 62/200 [14:45<23:11, 10.08s/it, loss=0.679, categorical_accuracy=0.765]
#
#
# Epoch 7:  31%|███       | 62/200 [14:45<23:11, 10.08s/it, loss=0.605, categorical_accuracy=0.774]
#
#
# Epoch 7:  32%|███▏      | 63/200 [14:53<21:23,  9.37s/it, loss=0.605, categorical_accuracy=0.774]
#
#
# Epoch 7:  32%|███▏      | 63/200 [14:53<21:23,  9.37s/it, loss=0.635, categorical_accuracy=0.784]
#
#
# Epoch 7:  32%|███▏      | 64/200 [15:01<20:30,  9.05s/it, loss=0.635, categorical_accuracy=0.784]
#
#
# Epoch 7:  32%|███▏      | 64/200 [15:01<20:30,  9.05s/it, loss=0.577, categorical_accuracy=0.805]
#
#
# Epoch 7:  32%|███▎      | 65/200 [15:49<46:37, 20.72s/it, loss=0.577, categorical_accuracy=0.805]
#
#
# Epoch 7:  32%|███▎      | 65/200 [15:49<46:37, 20.72s/it, loss=0.672, categorical_accuracy=0.759]
#
#
# Epoch 7:  33%|███▎      | 66/200 [15:57<37:50, 16.95s/it, loss=0.672, categorical_accuracy=0.759]
#
#
# Epoch 7:  33%|███▎      | 66/200 [15:57<37:50, 16.95s/it, loss=0.565, categorical_accuracy=0.794]
#
#
# Epoch 7:  34%|███▎      | 67/200 [16:06<32:00, 14.44s/it, loss=0.565, categorical_accuracy=0.794]
#
#
# Epoch 7:  34%|███▎      | 67/200 [16:06<32:00, 14.44s/it, loss=0.556, categorical_accuracy=0.81]
#
#
# Epoch 7:  34%|███▍      | 68/200 [16:13<27:12, 12.37s/it, loss=0.556, categorical_accuracy=0.81]
#
#
# Epoch 7:  34%|███▍      | 68/200 [16:13<27:12, 12.37s/it, loss=0.623, categorical_accuracy=0.757]
#
#
# Epoch 7:  34%|███▍      | 69/200 [16:21<24:12, 11.09s/it, loss=0.623, categorical_accuracy=0.757]
#
#
# Epoch 7:  34%|███▍      | 69/200 [16:21<24:12, 11.09s/it, loss=0.674, categorical_accuracy=0.75]
#
#
# Epoch 7:  35%|███▌      | 70/200 [16:29<22:05, 10.20s/it, loss=0.674, categorical_accuracy=0.75]
#
#
# Epoch 7:  35%|███▌      | 70/200 [16:29<22:05, 10.20s/it, loss=0.668, categorical_accuracy=0.743]
#
#
# Epoch 7:  36%|███▌      | 71/200 [16:38<20:46,  9.66s/it, loss=0.668, categorical_accuracy=0.743]
#
#
# Epoch 7:  36%|███▌      | 71/200 [16:38<20:46,  9.66s/it, loss=0.54, categorical_accuracy=0.805]
#
#
# Epoch 7:  36%|███▌      | 72/200 [16:46<19:48,  9.28s/it, loss=0.54, categorical_accuracy=0.805]
#
#
# Epoch 7:  36%|███▌      | 72/200 [16:46<19:48,  9.28s/it, loss=0.59, categorical_accuracy=0.79]
#
#
# Epoch 7:  36%|███▋      | 73/200 [17:34<43:56, 20.76s/it, loss=0.59, categorical_accuracy=0.79]
#
#
# Epoch 7:  36%|███▋      | 73/200 [17:34<43:56, 20.76s/it, loss=0.556, categorical_accuracy=0.781]
#
#
# Epoch 7:  37%|███▋      | 74/200 [17:42<35:25, 16.87s/it, loss=0.556, categorical_accuracy=0.781]
#
#
# Epoch 7:  37%|███▋      | 74/200 [17:42<35:25, 16.87s/it, loss=0.652, categorical_accuracy=0.76]
#
#
# Epoch 7:  38%|███▊      | 75/200 [17:50<30:09, 14.48s/it, loss=0.652, categorical_accuracy=0.76]
#
#
# Epoch 7:  38%|███▊      | 75/200 [17:50<30:09, 14.48s/it, loss=0.527, categorical_accuracy=0.802]
#
#
# Epoch 7:  38%|███▊      | 76/200 [17:59<26:04, 12.62s/it, loss=0.527, categorical_accuracy=0.802]
#
#
# Epoch 7:  38%|███▊      | 76/200 [17:59<26:04, 12.62s/it, loss=0.608, categorical_accuracy=0.75]
#
#
# Epoch 7:  38%|███▊      | 77/200 [18:07<22:56, 11.19s/it, loss=0.608, categorical_accuracy=0.75]
#
#
# Epoch 7:  38%|███▊      | 77/200 [18:07<22:56, 11.19s/it, loss=0.571, categorical_accuracy=0.789]
#
#
# Epoch 7:  39%|███▉      | 78/200 [18:15<21:00, 10.33s/it, loss=0.571, categorical_accuracy=0.789]
#
#
# Epoch 7:  39%|███▉      | 78/200 [18:15<21:00, 10.33s/it, loss=0.697, categorical_accuracy=0.735]
#
#
# Epoch 7:  40%|███▉      | 79/200 [18:23<19:30,  9.67s/it, loss=0.697, categorical_accuracy=0.735]
#
#
# Epoch 7:  40%|███▉      | 79/200 [18:23<19:30,  9.67s/it, loss=0.577, categorical_accuracy=0.791]
#
#
# Epoch 7:  40%|████      | 80/200 [18:32<18:38,  9.32s/it, loss=0.577, categorical_accuracy=0.791]
#
#
# Epoch 7:  40%|████      | 80/200 [18:32<18:38,  9.32s/it, loss=0.675, categorical_accuracy=0.762]
#
#
# Epoch 7:  40%|████      | 81/200 [19:20<41:45, 21.06s/it, loss=0.675, categorical_accuracy=0.762]
#
#
# Epoch 7:  40%|████      | 81/200 [19:20<41:45, 21.06s/it, loss=0.598, categorical_accuracy=0.779]
#
#
# Epoch 7:  41%|████      | 82/200 [19:29<34:01, 17.30s/it, loss=0.598, categorical_accuracy=0.779]
#
#
# Epoch 7:  41%|████      | 82/200 [19:29<34:01, 17.30s/it, loss=0.521, categorical_accuracy=0.821]
#
#
# Epoch 7:  42%|████▏     | 83/200 [19:36<28:08, 14.43s/it, loss=0.521, categorical_accuracy=0.821]
#
#
# Epoch 7:  42%|████▏     | 83/200 [19:36<28:08, 14.43s/it, loss=0.622, categorical_accuracy=0.776]
#
#
# Epoch 7:  42%|████▏     | 84/200 [19:45<24:26, 12.64s/it, loss=0.622, categorical_accuracy=0.776]
#
#
# Epoch 7:  42%|████▏     | 84/200 [19:45<24:26, 12.64s/it, loss=0.607, categorical_accuracy=0.792]
#
#
# Epoch 7:  42%|████▎     | 85/200 [19:52<21:24, 11.17s/it, loss=0.607, categorical_accuracy=0.792]
#
#
# Epoch 7:  42%|████▎     | 85/200 [19:52<21:24, 11.17s/it, loss=0.573, categorical_accuracy=0.796]
#
#
# Epoch 7:  43%|████▎     | 86/200 [20:01<19:36, 10.32s/it, loss=0.573, categorical_accuracy=0.796]
#
#
# Epoch 7:  43%|████▎     | 86/200 [20:01<19:36, 10.32s/it, loss=0.635, categorical_accuracy=0.769]
#
#
# Epoch 7:  44%|████▎     | 87/200 [20:09<18:11,  9.66s/it, loss=0.635, categorical_accuracy=0.769]
#
#
# Epoch 7:  44%|████▎     | 87/200 [20:09<18:11,  9.66s/it, loss=0.707, categorical_accuracy=0.736]
#
#
# Epoch 7:  44%|████▍     | 88/200 [20:18<17:28,  9.37s/it, loss=0.707, categorical_accuracy=0.736]
#
#
# Epoch 7:  44%|████▍     | 88/200 [20:18<17:28,  9.37s/it, loss=0.613, categorical_accuracy=0.777]
#
#
# Epoch 7:  44%|████▍     | 89/200 [21:05<38:41, 20.91s/it, loss=0.613, categorical_accuracy=0.777]
#
#
# Epoch 7:  44%|████▍     | 89/200 [21:05<38:41, 20.91s/it, loss=0.605, categorical_accuracy=0.795]
#
#
# Epoch 7:  45%|████▌     | 90/200 [21:14<31:26, 17.15s/it, loss=0.605, categorical_accuracy=0.795]
#
#
# Epoch 7:  45%|████▌     | 90/200 [21:14<31:26, 17.15s/it, loss=0.642, categorical_accuracy=0.757]
#
#
# Epoch 7:  46%|████▌     | 91/200 [21:22<26:21, 14.50s/it, loss=0.642, categorical_accuracy=0.757]
#
#
# Epoch 7:  46%|████▌     | 91/200 [21:22<26:21, 14.50s/it, loss=0.586, categorical_accuracy=0.777]
#
#
# Epoch 7:  46%|████▌     | 92/200 [21:30<22:34, 12.54s/it, loss=0.586, categorical_accuracy=0.777]
#
#
# Epoch 7:  46%|████▌     | 92/200 [21:30<22:34, 12.54s/it, loss=0.652, categorical_accuracy=0.756]
#
#
# Epoch 7:  46%|████▋     | 93/200 [21:38<20:04, 11.26s/it, loss=0.652, categorical_accuracy=0.756]
#
#
# Epoch 7:  46%|████▋     | 93/200 [21:38<20:04, 11.26s/it, loss=0.642, categorical_accuracy=0.772]
#
#
# Epoch 7:  47%|████▋     | 94/200 [21:47<18:16, 10.34s/it, loss=0.642, categorical_accuracy=0.772]
#
#
# Epoch 7:  47%|████▋     | 94/200 [21:47<18:16, 10.34s/it, loss=0.664, categorical_accuracy=0.744]
#
#
# Epoch 7:  48%|████▊     | 95/200 [21:55<17:20,  9.91s/it, loss=0.664, categorical_accuracy=0.744]
#
#
# Epoch 7:  48%|████▊     | 95/200 [21:55<17:20,  9.91s/it, loss=0.674, categorical_accuracy=0.764]
#
#
# Epoch 7:  48%|████▊     | 96/200 [22:04<16:17,  9.40s/it, loss=0.674, categorical_accuracy=0.764]
#
#
# Epoch 7:  48%|████▊     | 96/200 [22:04<16:17,  9.40s/it, loss=0.57, categorical_accuracy=0.781]
#
#
# Epoch 7:  48%|████▊     | 97/200 [22:50<35:05, 20.44s/it, loss=0.57, categorical_accuracy=0.781]
#
#
# Epoch 7:  48%|████▊     | 97/200 [22:50<35:05, 20.44s/it, loss=0.597, categorical_accuracy=0.796]
#
#
# Epoch 7:  49%|████▉     | 98/200 [22:58<28:32, 16.79s/it, loss=0.597, categorical_accuracy=0.796]
#
#
# Epoch 7:  49%|████▉     | 98/200 [22:58<28:32, 16.79s/it, loss=0.735, categorical_accuracy=0.731]
#
#
# Epoch 7:  50%|████▉     | 99/200 [23:07<24:12, 14.38s/it, loss=0.735, categorical_accuracy=0.731]
#
#
# Epoch 7:  50%|████▉     | 99/200 [23:07<24:12, 14.38s/it, loss=0.693, categorical_accuracy=0.735]
#
#
# Epoch 7:  50%|█████     | 100/200 [23:15<20:56, 12.57s/it, loss=0.693, categorical_accuracy=0.735]
#
#
# Epoch 7:  50%|█████     | 100/200 [23:15<20:56, 12.57s/it, loss=0.592, categorical_accuracy=0.794]
#
#
# Epoch 7:  50%|█████     | 101/200 [23:23<18:26, 11.18s/it, loss=0.592, categorical_accuracy=0.794]
#
#
# Epoch 7:  50%|█████     | 101/200 [23:23<18:26, 11.18s/it, loss=0.696, categorical_accuracy=0.74]
#
#
# Epoch 7:  51%|█████     | 102/200 [23:32<17:03, 10.44s/it, loss=0.696, categorical_accuracy=0.74]
#
#
# Epoch 7:  51%|█████     | 102/200 [23:32<17:03, 10.44s/it, loss=0.551, categorical_accuracy=0.8]
#
#
# Epoch 7:  52%|█████▏    | 103/200 [23:40<15:56,  9.86s/it, loss=0.551, categorical_accuracy=0.8]
#
#
# Epoch 7:  52%|█████▏    | 103/200 [23:40<15:56,  9.86s/it, loss=0.674, categorical_accuracy=0.765]
#
#
# Epoch 7:  52%|█████▏    | 104/200 [23:49<14:58,  9.36s/it, loss=0.674, categorical_accuracy=0.765]
#
#
# Epoch 7:  52%|█████▏    | 104/200 [23:49<14:58,  9.36s/it, loss=0.603, categorical_accuracy=0.774]
#
#
# Epoch 7:  52%|█████▎    | 105/200 [24:36<32:41, 20.65s/it, loss=0.603, categorical_accuracy=0.774]
#
#
# Epoch 7:  52%|█████▎    | 105/200 [24:36<32:41, 20.65s/it, loss=0.641, categorical_accuracy=0.785]
#
#
# Epoch 7:  53%|█████▎    | 106/200 [24:43<26:14, 16.75s/it, loss=0.641, categorical_accuracy=0.785]
#
#
# Epoch 7:  53%|█████▎    | 106/200 [24:43<26:14, 16.75s/it, loss=0.692, categorical_accuracy=0.74]
#
#
# Epoch 7:  54%|█████▎    | 107/200 [24:51<21:52, 14.11s/it, loss=0.692, categorical_accuracy=0.74]
#
#
# Epoch 7:  54%|█████▎    | 107/200 [24:51<21:52, 14.11s/it, loss=0.713, categorical_accuracy=0.739]
#
#
# Epoch 7:  54%|█████▍    | 108/200 [25:00<19:02, 12.42s/it, loss=0.713, categorical_accuracy=0.739]
#
#
# Epoch 7:  54%|█████▍    | 108/200 [25:00<19:02, 12.42s/it, loss=0.566, categorical_accuracy=0.789]
#
#
# Epoch 7:  55%|█████▍    | 109/200 [25:08<16:58, 11.20s/it, loss=0.566, categorical_accuracy=0.789]
#
#
# Epoch 7:  55%|█████▍    | 109/200 [25:08<16:58, 11.20s/it, loss=0.661, categorical_accuracy=0.767]
#
#
# Epoch 7:  55%|█████▌    | 110/200 [25:17<15:46, 10.51s/it, loss=0.661, categorical_accuracy=0.767]
#
#
# Epoch 7:  55%|█████▌    | 110/200 [25:17<15:46, 10.51s/it, loss=0.651, categorical_accuracy=0.762]
#
#
# Epoch 7:  56%|█████▌    | 111/200 [25:25<14:21,  9.68s/it, loss=0.651, categorical_accuracy=0.762]
#
#
# Epoch 7:  56%|█████▌    | 111/200 [25:25<14:21,  9.68s/it, loss=0.708, categorical_accuracy=0.733]
#
#
# Epoch 7:  56%|█████▌    | 112/200 [25:33<13:26,  9.16s/it, loss=0.708, categorical_accuracy=0.733]
#
#
# Epoch 7:  56%|█████▌    | 112/200 [25:33<13:26,  9.16s/it, loss=0.606, categorical_accuracy=0.802]
#
#
# Epoch 7:  56%|█████▋    | 113/200 [26:23<30:59, 21.37s/it, loss=0.606, categorical_accuracy=0.802]
#
#
# Epoch 7:  56%|█████▋    | 113/200 [26:23<30:59, 21.37s/it, loss=0.599, categorical_accuracy=0.775]
#
#
# Epoch 7:  57%|█████▋    | 114/200 [26:31<25:12, 17.58s/it, loss=0.599, categorical_accuracy=0.775]
#
#
# Epoch 7:  57%|█████▋    | 114/200 [26:31<25:12, 17.58s/it, loss=0.585, categorical_accuracy=0.782]
#
#
# Epoch 7:  57%|█████▊    | 115/200 [26:39<20:49, 14.70s/it, loss=0.585, categorical_accuracy=0.782]
#
#
# Epoch 7:  57%|█████▊    | 115/200 [26:39<20:49, 14.70s/it, loss=0.56, categorical_accuracy=0.806]
#
#
# Epoch 7:  58%|█████▊    | 116/200 [26:47<17:52, 12.77s/it, loss=0.56, categorical_accuracy=0.806]
#
#
# Epoch 7:  58%|█████▊    | 116/200 [26:47<17:52, 12.77s/it, loss=0.579, categorical_accuracy=0.781]
#
#
# Epoch 7:  58%|█████▊    | 117/200 [26:56<15:53, 11.49s/it, loss=0.579, categorical_accuracy=0.781]
#
#
# Epoch 7:  58%|█████▊    | 117/200 [26:56<15:53, 11.49s/it, loss=0.601, categorical_accuracy=0.776]
#
#
# Epoch 7:  59%|█████▉    | 118/200 [27:04<14:21, 10.51s/it, loss=0.601, categorical_accuracy=0.776]
#
#
# Epoch 7:  59%|█████▉    | 118/200 [27:04<14:21, 10.51s/it, loss=0.684, categorical_accuracy=0.762]
#
#
# Epoch 7:  60%|█████▉    | 119/200 [27:13<13:22,  9.91s/it, loss=0.684, categorical_accuracy=0.762]
#
#
# Epoch 7:  60%|█████▉    | 119/200 [27:13<13:22,  9.91s/it, loss=0.59, categorical_accuracy=0.797]
#
#
# Epoch 7:  60%|██████    | 120/200 [27:21<12:38,  9.48s/it, loss=0.59, categorical_accuracy=0.797]
#
#
# Epoch 7:  60%|██████    | 120/200 [27:21<12:38,  9.48s/it, loss=0.583, categorical_accuracy=0.801]
#
#
# Epoch 7:  60%|██████    | 121/200 [28:08<27:12, 20.67s/it, loss=0.583, categorical_accuracy=0.801]
#
#
# Epoch 7:  60%|██████    | 121/200 [28:08<27:12, 20.67s/it, loss=0.587, categorical_accuracy=0.797]
#
#
# Epoch 7:  61%|██████    | 122/200 [28:17<22:12, 17.09s/it, loss=0.587, categorical_accuracy=0.797]
#
#
# Epoch 7:  61%|██████    | 122/200 [28:17<22:12, 17.09s/it, loss=0.58, categorical_accuracy=0.797]
#
#
# Epoch 7:  62%|██████▏   | 123/200 [28:25<18:34, 14.47s/it, loss=0.58, categorical_accuracy=0.797]
#
#
# Epoch 7:  62%|██████▏   | 123/200 [28:25<18:34, 14.47s/it, loss=0.569, categorical_accuracy=0.812]
#
#
# Epoch 7:  62%|██████▏   | 124/200 [28:33<15:51, 12.52s/it, loss=0.569, categorical_accuracy=0.812]
#
#
# Epoch 7:  62%|██████▏   | 124/200 [28:33<15:51, 12.52s/it, loss=0.592, categorical_accuracy=0.787]
#
#
# Epoch 7:  62%|██████▎   | 125/200 [28:42<14:16, 11.42s/it, loss=0.592, categorical_accuracy=0.787]
#
#
# Epoch 7:  62%|██████▎   | 125/200 [28:42<14:16, 11.42s/it, loss=0.556, categorical_accuracy=0.809]
#
#
# Epoch 7:  63%|██████▎   | 126/200 [28:50<12:46, 10.35s/it, loss=0.556, categorical_accuracy=0.809]
#
#
# Epoch 7:  63%|██████▎   | 126/200 [28:50<12:46, 10.35s/it, loss=0.574, categorical_accuracy=0.787]
#
#
# Epoch 7:  64%|██████▎   | 127/200 [28:57<11:38,  9.56s/it, loss=0.574, categorical_accuracy=0.787]
#
#
# Epoch 7:  64%|██████▎   | 127/200 [28:57<11:38,  9.56s/it, loss=0.691, categorical_accuracy=0.764]
#
#
# Epoch 7:  64%|██████▍   | 128/200 [29:05<10:52,  9.07s/it, loss=0.691, categorical_accuracy=0.764]
#
#
# Epoch 7:  64%|██████▍   | 128/200 [29:05<10:52,  9.07s/it, loss=0.528, categorical_accuracy=0.824]
#
#
# Epoch 7:  64%|██████▍   | 129/200 [29:54<24:43, 20.89s/it, loss=0.528, categorical_accuracy=0.824]
#
#
# Epoch 7:  64%|██████▍   | 129/200 [29:54<24:43, 20.89s/it, loss=0.598, categorical_accuracy=0.805]
#
#
# Epoch 7:  65%|██████▌   | 130/200 [30:02<19:54, 17.06s/it, loss=0.598, categorical_accuracy=0.805]
#
#
# Epoch 7:  65%|██████▌   | 130/200 [30:02<19:54, 17.06s/it, loss=0.573, categorical_accuracy=0.826]
#
#
# Epoch 7:  66%|██████▌   | 131/200 [30:10<16:37, 14.46s/it, loss=0.573, categorical_accuracy=0.826]
#
#
# Epoch 7:  66%|██████▌   | 131/200 [30:10<16:37, 14.46s/it, loss=0.566, categorical_accuracy=0.782]
#
#
# Epoch 7:  66%|██████▌   | 132/200 [30:18<14:07, 12.46s/it, loss=0.566, categorical_accuracy=0.782]
#
#
# Epoch 7:  66%|██████▌   | 132/200 [30:18<14:07, 12.46s/it, loss=0.551, categorical_accuracy=0.818]
#
#
# Epoch 7:  66%|██████▋   | 133/200 [30:27<12:33, 11.25s/it, loss=0.551, categorical_accuracy=0.818]
#
#
# Epoch 7:  66%|██████▋   | 133/200 [30:27<12:33, 11.25s/it, loss=0.642, categorical_accuracy=0.787]
#
#
# Epoch 7:  67%|██████▋   | 134/200 [30:34<11:03, 10.05s/it, loss=0.642, categorical_accuracy=0.787]
#
#
# Epoch 7:  67%|██████▋   | 134/200 [30:34<11:03, 10.05s/it, loss=0.591, categorical_accuracy=0.805]
#
#
# Epoch 7:  68%|██████▊   | 135/200 [30:42<10:24,  9.61s/it, loss=0.591, categorical_accuracy=0.805]
#
#
# Epoch 7:  68%|██████▊   | 135/200 [30:42<10:24,  9.61s/it, loss=0.594, categorical_accuracy=0.823]
#
#
# Epoch 7:  68%|██████▊   | 136/200 [30:51<09:55,  9.31s/it, loss=0.594, categorical_accuracy=0.823]
#
#
# Epoch 7:  68%|██████▊   | 136/200 [30:51<09:55,  9.31s/it, loss=0.567, categorical_accuracy=0.804]
#
#
# Epoch 7:  68%|██████▊   | 137/200 [31:41<22:41, 21.61s/it, loss=0.567, categorical_accuracy=0.804]
#
#
# Epoch 7:  68%|██████▊   | 137/200 [31:41<22:41, 21.61s/it, loss=0.609, categorical_accuracy=0.776]
#
#
# Epoch 7:  69%|██████▉   | 138/200 [31:50<18:27, 17.87s/it, loss=0.609, categorical_accuracy=0.776]
#
#
# Epoch 7:  69%|██████▉   | 138/200 [31:50<18:27, 17.87s/it, loss=0.62, categorical_accuracy=0.781]
#
#
# Epoch 7:  70%|██████▉   | 139/200 [31:59<15:19, 15.07s/it, loss=0.62, categorical_accuracy=0.781]
#
#
# Epoch 7:  70%|██████▉   | 139/200 [31:59<15:19, 15.07s/it, loss=0.546, categorical_accuracy=0.816]
#
#
# Epoch 7:  70%|███████   | 140/200 [32:08<13:06, 13.11s/it, loss=0.546, categorical_accuracy=0.816]
#
#
# Epoch 7:  70%|███████   | 140/200 [32:08<13:06, 13.11s/it, loss=0.652, categorical_accuracy=0.769]
#
#
# Epoch 7:  70%|███████   | 141/200 [32:17<11:40, 11.88s/it, loss=0.652, categorical_accuracy=0.769]
#
#
# Epoch 7:  70%|███████   | 141/200 [32:17<11:40, 11.88s/it, loss=0.585, categorical_accuracy=0.801]
#
#
# Epoch 7:  71%|███████   | 142/200 [32:25<10:33, 10.92s/it, loss=0.585, categorical_accuracy=0.801]
#
#
# Epoch 7:  71%|███████   | 142/200 [32:25<10:33, 10.92s/it, loss=0.606, categorical_accuracy=0.791]
#
#
# Epoch 7:  72%|███████▏  | 143/200 [32:34<09:42, 10.22s/it, loss=0.606, categorical_accuracy=0.791]
#
#
# Epoch 7:  72%|███████▏  | 143/200 [32:34<09:42, 10.22s/it, loss=0.591, categorical_accuracy=0.805]
#
#
# Epoch 7:  72%|███████▏  | 144/200 [32:42<09:01,  9.68s/it, loss=0.591, categorical_accuracy=0.805]
#
#
# Epoch 7:  72%|███████▏  | 144/200 [32:42<09:01,  9.68s/it, loss=0.57, categorical_accuracy=0.81]
#
#
# Epoch 7:  72%|███████▎  | 145/200 [33:27<18:29, 20.17s/it, loss=0.57, categorical_accuracy=0.81]
#
#
# Epoch 7:  72%|███████▎  | 145/200 [33:27<18:29, 20.17s/it, loss=0.589, categorical_accuracy=0.785]
#
#
# Epoch 7:  73%|███████▎  | 146/200 [33:36<15:03, 16.72s/it, loss=0.589, categorical_accuracy=0.785]
#
#
# Epoch 7:  73%|███████▎  | 146/200 [33:36<15:03, 16.72s/it, loss=0.596, categorical_accuracy=0.781]
#
#
# Epoch 7:  74%|███████▎  | 147/200 [33:44<12:38, 14.31s/it, loss=0.596, categorical_accuracy=0.781]
#
#
# Epoch 7:  74%|███████▎  | 147/200 [33:44<12:38, 14.31s/it, loss=0.553, categorical_accuracy=0.805]
#
#
# Epoch 7:  74%|███████▍  | 148/200 [33:52<10:43, 12.37s/it, loss=0.553, categorical_accuracy=0.805]
#
#
# Epoch 7:  74%|███████▍  | 148/200 [33:52<10:43, 12.37s/it, loss=0.499, categorical_accuracy=0.83]
#
#
# Epoch 7:  74%|███████▍  | 149/200 [34:01<09:33, 11.25s/it, loss=0.499, categorical_accuracy=0.83]
#
#
# Epoch 7:  74%|███████▍  | 149/200 [34:01<09:33, 11.25s/it, loss=0.641, categorical_accuracy=0.775]
#
#
# Epoch 7:  75%|███████▌  | 150/200 [34:10<08:46, 10.54s/it, loss=0.641, categorical_accuracy=0.775]
#
#
# Epoch 7:  75%|███████▌  | 150/200 [34:10<08:46, 10.54s/it, loss=0.684, categorical_accuracy=0.757]
#
#
# Epoch 7:  76%|███████▌  | 151/200 [34:18<08:10, 10.01s/it, loss=0.684, categorical_accuracy=0.757]
#
#
# Epoch 7:  76%|███████▌  | 151/200 [34:18<08:10, 10.01s/it, loss=0.597, categorical_accuracy=0.765]
#
#
# Epoch 7:  76%|███████▌  | 152/200 [34:27<07:35,  9.50s/it, loss=0.597, categorical_accuracy=0.765]
#
#
# Epoch 7:  76%|███████▌  | 152/200 [34:27<07:35,  9.50s/it, loss=0.604, categorical_accuracy=0.801]
#
#
# Epoch 7:  76%|███████▋  | 153/200 [35:13<16:09, 20.63s/it, loss=0.604, categorical_accuracy=0.801]
#
#
# Epoch 7:  76%|███████▋  | 153/200 [35:13<16:09, 20.63s/it, loss=0.494, categorical_accuracy=0.836]
#
#
# Epoch 7:  77%|███████▋  | 154/200 [35:22<13:00, 16.97s/it, loss=0.494, categorical_accuracy=0.836]
#
#
# Epoch 7:  77%|███████▋  | 154/200 [35:22<13:00, 16.97s/it, loss=0.57, categorical_accuracy=0.791]
#
#
# Epoch 7:  78%|███████▊  | 155/200 [35:31<10:55, 14.57s/it, loss=0.57, categorical_accuracy=0.791]
#
#
# Epoch 7:  78%|███████▊  | 155/200 [35:31<10:55, 14.57s/it, loss=0.559, categorical_accuracy=0.792]
#
#
# Epoch 7:  78%|███████▊  | 156/200 [35:39<09:22, 12.79s/it, loss=0.559, categorical_accuracy=0.792]
#
#
# Epoch 7:  78%|███████▊  | 156/200 [35:39<09:22, 12.79s/it, loss=0.669, categorical_accuracy=0.781]
#
#
# Epoch 7:  78%|███████▊  | 157/200 [35:48<08:13, 11.49s/it, loss=0.669, categorical_accuracy=0.781]
#
#
# Epoch 7:  78%|███████▊  | 157/200 [35:48<08:13, 11.49s/it, loss=0.692, categorical_accuracy=0.749]
#
#
# Epoch 7:  79%|███████▉  | 158/200 [35:56<07:24, 10.57s/it, loss=0.692, categorical_accuracy=0.749]
#
#
# Epoch 7:  79%|███████▉  | 158/200 [35:56<07:24, 10.57s/it, loss=0.574, categorical_accuracy=0.805]
#
#
# Epoch 7:  80%|███████▉  | 159/200 [36:05<06:53, 10.09s/it, loss=0.574, categorical_accuracy=0.805]
#
#
# Epoch 7:  80%|███████▉  | 159/200 [36:05<06:53, 10.09s/it, loss=0.513, categorical_accuracy=0.836]
#
#
# Epoch 7:  80%|████████  | 160/200 [36:14<06:24,  9.61s/it, loss=0.513, categorical_accuracy=0.836]
#
#
# Epoch 7:  80%|████████  | 160/200 [36:14<06:24,  9.61s/it, loss=0.554, categorical_accuracy=0.816]
#
#
# Epoch 7:  80%|████████  | 161/200 [36:59<13:12, 20.32s/it, loss=0.554, categorical_accuracy=0.816]
#
#
# Epoch 7:  80%|████████  | 161/200 [36:59<13:12, 20.32s/it, loss=0.581, categorical_accuracy=0.801]
#
#
# Epoch 7:  81%|████████  | 162/200 [37:08<10:41, 16.88s/it, loss=0.581, categorical_accuracy=0.801]
#
#
# Epoch 7:  81%|████████  | 162/200 [37:08<10:41, 16.88s/it, loss=0.521, categorical_accuracy=0.81]
#
#
# Epoch 7:  82%|████████▏ | 163/200 [37:17<08:56, 14.49s/it, loss=0.521, categorical_accuracy=0.81]
#
#
# Epoch 7:  82%|████████▏ | 163/200 [37:17<08:56, 14.49s/it, loss=0.628, categorical_accuracy=0.784]
#
#
# Epoch 7:  82%|████████▏ | 164/200 [37:26<07:41, 12.82s/it, loss=0.628, categorical_accuracy=0.784]
#
#
# Epoch 7:  82%|████████▏ | 164/200 [37:26<07:41, 12.82s/it, loss=0.526, categorical_accuracy=0.799]
#
#
# Epoch 7:  82%|████████▎ | 165/200 [37:34<06:42, 11.51s/it, loss=0.526, categorical_accuracy=0.799]
#
#
# Epoch 7:  82%|████████▎ | 165/200 [37:34<06:42, 11.51s/it, loss=0.628, categorical_accuracy=0.769]
#
#
# Epoch 7:  83%|████████▎ | 166/200 [37:43<05:59, 10.58s/it, loss=0.628, categorical_accuracy=0.769]
#
#
# Epoch 7:  83%|████████▎ | 166/200 [37:43<05:59, 10.58s/it, loss=0.645, categorical_accuracy=0.744]
#
#
# Epoch 7:  84%|████████▎ | 167/200 [37:51<05:27,  9.91s/it, loss=0.645, categorical_accuracy=0.744]
#
#
# Epoch 7:  84%|████████▎ | 167/200 [37:51<05:27,  9.91s/it, loss=0.635, categorical_accuracy=0.791]
#
#
# Epoch 7:  84%|████████▍ | 168/200 [38:00<05:08,  9.63s/it, loss=0.635, categorical_accuracy=0.791]
#
#
# Epoch 7:  84%|████████▍ | 168/200 [38:00<05:08,  9.63s/it, loss=0.589, categorical_accuracy=0.807]
#
#
# Epoch 7:  84%|████████▍ | 169/200 [38:45<10:24, 20.14s/it, loss=0.589, categorical_accuracy=0.807]
#
#
# Epoch 7:  84%|████████▍ | 169/200 [38:45<10:24, 20.14s/it, loss=0.628, categorical_accuracy=0.777]
#
#
# Epoch 7:  85%|████████▌ | 170/200 [38:53<08:16, 16.56s/it, loss=0.628, categorical_accuracy=0.777]
#
#
# Epoch 7:  85%|████████▌ | 170/200 [38:53<08:16, 16.56s/it, loss=0.521, categorical_accuracy=0.816]
#
#
# Epoch 7:  86%|████████▌ | 171/200 [39:02<06:52, 14.24s/it, loss=0.521, categorical_accuracy=0.816]
#
#
# Epoch 7:  86%|████████▌ | 171/200 [39:02<06:52, 14.24s/it, loss=0.613, categorical_accuracy=0.792]
#
#
# Epoch 7:  86%|████████▌ | 172/200 [39:09<05:44, 12.30s/it, loss=0.613, categorical_accuracy=0.792]
#
#
# Epoch 7:  86%|████████▌ | 172/200 [39:09<05:44, 12.30s/it, loss=0.55, categorical_accuracy=0.809]
#
#
# Epoch 7:  86%|████████▋ | 173/200 [39:18<05:02, 11.19s/it, loss=0.55, categorical_accuracy=0.809]
#
#
# Epoch 7:  86%|████████▋ | 173/200 [39:18<05:02, 11.19s/it, loss=0.657, categorical_accuracy=0.775]
#
#
# Epoch 7:  87%|████████▋ | 174/200 [39:26<04:27, 10.27s/it, loss=0.657, categorical_accuracy=0.775]
#
#
# Epoch 7:  87%|████████▋ | 174/200 [39:26<04:27, 10.27s/it, loss=0.521, categorical_accuracy=0.833]
#
#
# Epoch 7:  88%|████████▊ | 175/200 [39:34<04:02,  9.70s/it, loss=0.521, categorical_accuracy=0.833]
#
#
# Epoch 7:  88%|████████▊ | 175/200 [39:34<04:02,  9.70s/it, loss=0.596, categorical_accuracy=0.792]
#
#
# Epoch 7:  88%|████████▊ | 176/200 [39:43<03:43,  9.33s/it, loss=0.596, categorical_accuracy=0.792]
#
#
# Epoch 7:  88%|████████▊ | 176/200 [39:43<03:43,  9.33s/it, loss=0.659, categorical_accuracy=0.765]
#
#
# Epoch 7:  88%|████████▊ | 177/200 [40:29<07:46, 20.30s/it, loss=0.659, categorical_accuracy=0.765]
#
#
# Epoch 7:  88%|████████▊ | 177/200 [40:29<07:46, 20.30s/it, loss=0.584, categorical_accuracy=0.802]
#
#
# Epoch 7:  89%|████████▉ | 178/200 [40:37<06:09, 16.78s/it, loss=0.584, categorical_accuracy=0.802]
#
#
# Epoch 7:  89%|████████▉ | 178/200 [40:37<06:09, 16.78s/it, loss=0.586, categorical_accuracy=0.79]
#
#
# Epoch 7:  90%|████████▉ | 179/200 [40:46<04:58, 14.20s/it, loss=0.586, categorical_accuracy=0.79]
#
#
# Epoch 7:  90%|████████▉ | 179/200 [40:46<04:58, 14.20s/it, loss=0.664, categorical_accuracy=0.786]
#
#
# Epoch 7:  90%|█████████ | 180/200 [40:53<04:06, 12.32s/it, loss=0.664, categorical_accuracy=0.786]
#
#
# Epoch 7:  90%|█████████ | 180/200 [40:53<04:06, 12.32s/it, loss=0.614, categorical_accuracy=0.79]
#
#
# Epoch 7:  90%|█████████ | 181/200 [41:01<03:27, 10.94s/it, loss=0.614, categorical_accuracy=0.79]
#
#
# Epoch 7:  90%|█████████ | 181/200 [41:01<03:27, 10.94s/it, loss=0.645, categorical_accuracy=0.779]
#
#
# Epoch 7:  91%|█████████ | 182/200 [41:09<03:02, 10.12s/it, loss=0.645, categorical_accuracy=0.779]
#
#
# Epoch 7:  91%|█████████ | 182/200 [41:09<03:02, 10.12s/it, loss=0.544, categorical_accuracy=0.818]
#
#
# Epoch 7:  92%|█████████▏| 183/200 [41:18<02:41,  9.52s/it, loss=0.544, categorical_accuracy=0.818]
#
#
# Epoch 7:  92%|█████████▏| 183/200 [41:18<02:41,  9.52s/it, loss=0.611, categorical_accuracy=0.775]
#
#
# Epoch 7:  92%|█████████▏| 184/200 [41:26<02:28,  9.26s/it, loss=0.611, categorical_accuracy=0.775]
#
#
# Epoch 7:  92%|█████████▏| 184/200 [41:26<02:28,  9.26s/it, loss=0.672, categorical_accuracy=0.779]
#
#
# Epoch 7:  92%|█████████▎| 185/200 [42:10<04:52, 19.52s/it, loss=0.672, categorical_accuracy=0.779]
#
#
# Epoch 7:  92%|█████████▎| 185/200 [42:10<04:52, 19.52s/it, loss=0.539, categorical_accuracy=0.815]
#
#
# Epoch 7:  93%|█████████▎| 186/200 [42:15<03:31, 15.14s/it, loss=0.539, categorical_accuracy=0.815]
#
#
# Epoch 7:  93%|█████████▎| 186/200 [42:15<03:31, 15.14s/it, loss=0.535, categorical_accuracy=0.823]
#
#
# Epoch 7:  94%|█████████▎| 187/200 [42:19<02:36, 12.02s/it, loss=0.535, categorical_accuracy=0.823]
#
#
# Epoch 7:  94%|█████████▎| 187/200 [42:19<02:36, 12.02s/it, loss=0.578, categorical_accuracy=0.801]
#
#
# Epoch 7:  94%|█████████▍| 188/200 [42:28<02:11, 10.94s/it, loss=0.578, categorical_accuracy=0.801]
#
#
# Epoch 7:  94%|█████████▍| 188/200 [42:28<02:11, 10.94s/it, loss=0.622, categorical_accuracy=0.792]
#
#
# Epoch 7:  94%|█████████▍| 189/200 [42:35<01:48,  9.90s/it, loss=0.622, categorical_accuracy=0.792]
#
#
# Epoch 7:  94%|█████████▍| 189/200 [42:35<01:48,  9.90s/it, loss=0.525, categorical_accuracy=0.82]
#
#
# Epoch 7:  95%|█████████▌| 190/200 [42:40<01:24,  8.40s/it, loss=0.525, categorical_accuracy=0.82]
#
#
# Epoch 7:  95%|█████████▌| 190/200 [42:40<01:24,  8.40s/it, loss=0.596, categorical_accuracy=0.787]
#
#
# Epoch 7:  96%|█████████▌| 191/200 [42:45<01:05,  7.32s/it, loss=0.596, categorical_accuracy=0.787]
#
#
# Epoch 7:  96%|█████████▌| 191/200 [42:45<01:05,  7.32s/it, loss=0.569, categorical_accuracy=0.805]
#
#
# Epoch 7:  96%|█████████▌| 192/200 [42:53<01:01,  7.68s/it, loss=0.569, categorical_accuracy=0.805]
#
#
# Epoch 7:  96%|█████████▌| 192/200 [42:53<01:01,  7.68s/it, loss=0.653, categorical_accuracy=0.77]
#
#
# Epoch 7:  96%|█████████▋| 193/200 [43:52<02:40, 22.99s/it, loss=0.653, categorical_accuracy=0.77]
#
#
# Epoch 7:  96%|█████████▋| 193/200 [43:52<02:40, 22.99s/it, loss=0.568, categorical_accuracy=0.812]
#
#
# Epoch 7:  97%|█████████▋| 194/200 [43:56<01:44, 17.38s/it, loss=0.568, categorical_accuracy=0.812]
#
#
# Epoch 7:  97%|█████████▋| 194/200 [43:56<01:44, 17.38s/it, loss=0.606, categorical_accuracy=0.789]
#
#
# Epoch 7:  98%|█████████▊| 195/200 [44:00<01:06, 13.38s/it, loss=0.606, categorical_accuracy=0.789]
#
#
# Epoch 7:  98%|█████████▊| 195/200 [44:00<01:06, 13.38s/it, loss=0.556, categorical_accuracy=0.833]
#
#
# Epoch 7:  98%|█████████▊| 196/200 [44:04<00:42, 10.54s/it, loss=0.556, categorical_accuracy=0.833]
#
#
# Epoch 7:  98%|█████████▊| 196/200 [44:04<00:42, 10.54s/it, loss=0.569, categorical_accuracy=0.812]
#
#
# Epoch 7:  98%|█████████▊| 197/200 [44:09<00:26,  8.70s/it, loss=0.569, categorical_accuracy=0.812]
#
#
# Epoch 7:  98%|█████████▊| 197/200 [44:09<00:26,  8.70s/it, loss=0.595, categorical_accuracy=0.779]
#
#
# Epoch 7:  99%|█████████▉| 198/200 [44:13<00:14,  7.22s/it, loss=0.595, categorical_accuracy=0.779]
#
#
# Epoch 7:  99%|█████████▉| 198/200 [44:13<00:14,  7.22s/it, loss=0.607, categorical_accuracy=0.799]
#
#
# Epoch 7: 100%|█████████▉| 199/200 [44:16<00:06,  6.18s/it, loss=0.607, categorical_accuracy=0.799]
#
#
# Epoch 7: 100%|█████████▉| 199/200 [44:16<00:06,  6.18s/it, loss=0.69, categorical_accuracy=0.751]
#
#
# Epoch 7: 100%|██████████| 200/200 [49:24<00:00, 96.69s/it, loss=0.69, categorical_accuracy=0.751]
#
#
# Epoch 7: 100%|██████████| 200/200 [49:24<00:00, 14.82s/it, loss=0.61, categorical_accuracy=0.784]
#
#
#
# Epoch 8:   0%|          | 0/200 [00:00<?, ?it/s]
#
#
# Epoch 8:   0%|          | 1/200 [01:48<5:59:02, 108.26s/it]
#
#
# Epoch 8:   0%|          | 1/200 [01:48<5:59:02, 108.26s/it, loss=0.613, categorical_accuracy=0.785]
#
#
# Epoch 8:   1%|          | 2/200 [01:56<4:18:08, 78.22s/it, loss=0.613, categorical_accuracy=0.785]
#
#
# Epoch 8:   1%|          | 2/200 [01:56<4:18:08, 78.22s/it, loss=0.547, categorical_accuracy=0.815]
#
#
# Epoch 8:   2%|▏         | 3/200 [02:04<3:07:39, 57.16s/it, loss=0.547, categorical_accuracy=0.815]
#
#
# Epoch 8:   2%|▏         | 3/200 [02:04<3:07:39, 57.16s/it, loss=0.595, categorical_accuracy=0.804]
#
#
# Epoch 8:   2%|▏         | 4/200 [02:12<2:18:41, 42.46s/it, loss=0.595, categorical_accuracy=0.804]
#
#
# Epoch 8:   2%|▏         | 4/200 [02:12<2:18:41, 42.46s/it, loss=0.579, categorical_accuracy=0.772]
#
#
# Epoch 8:   2%|▎         | 5/200 [02:21<1:44:59, 32.30s/it, loss=0.579, categorical_accuracy=0.772]
#
#
# Epoch 8:   2%|▎         | 5/200 [02:21<1:44:59, 32.30s/it, loss=0.574, categorical_accuracy=0.782]
#
#
# Epoch 8:   3%|▎         | 6/200 [02:30<1:21:52, 25.32s/it, loss=0.574, categorical_accuracy=0.782]
#
#
# Epoch 8:   3%|▎         | 6/200 [02:30<1:21:52, 25.32s/it, loss=0.491, categorical_accuracy=0.838]
#
#
# Epoch 8:   4%|▎         | 7/200 [02:38<1:05:15, 20.29s/it, loss=0.491, categorical_accuracy=0.838]
#
#
# ...
#
#
# Epoch 10:  62%|██████▏   | 123/200 [28:32<18:16, 14.24s/it, loss=0.49, categorical_accuracy=0.824]
#
#
# Epoch 10:  62%|██████▏   | 123/200 [28:32<18:16, 14.24s/it, loss=0.502, categorical_accuracy=0.833]
#
#
# Epoch 10:  62%|██████▏   | 124/200 [28:40<15:25, 12.18s/it, loss=0.502, categorical_accuracy=0.833]
#
#
# Epoch 10:  62%|██████▏   | 124/200 [28:40<15:25, 12.18s/it, loss=0.565, categorical_accuracy=0.791]
#
#
# Epoch 10:  62%|██████▎   | 125/200 [28:48<13:40, 10.94s/it, loss=0.565, categorical_accuracy=0.791]
#
#
# Epoch 10:  62%|██████▎   | 125/200 [28:48<13:40, 10.94s/it, loss=0.46, categorical_accuracy=0.845]
#
#
# Epoch 10:  63%|██████▎   | 126/200 [28:56<12:24, 10.06s/it, loss=0.46, categorical_accuracy=0.845]
#
#
# Epoch 10:  63%|██████▎   | 126/200 [28:56<12:24, 10.06s/it, loss=0.419, categorical_accuracy=0.858]
#
#
# Epoch 10:  64%|██████▎   | 127/200 [29:04<11:42,  9.63s/it, loss=0.419, categorical_accuracy=0.858]
#
#
# Epoch 10:  64%|██████▎   | 127/200 [29:04<11:42,  9.63s/it, loss=0.402, categorical_accuracy=0.874]
#
#
# Epoch 10:  64%|██████▍   | 128/200 [29:13<11:05,  9.24s/it, loss=0.402, categorical_accuracy=0.874]
#
#
# Epoch 10:  64%|██████▍   | 128/200 [29:13<11:05,  9.24s/it, loss=0.514, categorical_accuracy=0.806]
#
#
# Epoch 10:  64%|██████▍   | 129/200 [30:00<24:29, 20.70s/it, loss=0.514, categorical_accuracy=0.806]
#
#
# Epoch 10:  64%|██████▍   | 129/200 [30:00<24:29, 20.70s/it, loss=0.473, categorical_accuracy=0.849]
#
#
# Epoch 10:  65%|██████▌   | 130/200 [30:11<20:47, 17.83s/it, loss=0.473, categorical_accuracy=0.849]
#
#
# Epoch 10:  65%|██████▌   | 130/200 [30:11<20:47, 17.83s/it, loss=0.577, categorical_accuracy=0.828]
#
#
# Epoch 10:  66%|██████▌   | 131/200 [30:19<17:05, 14.86s/it, loss=0.577, categorical_accuracy=0.828]
#
#
# Epoch 10:  66%|██████▌   | 131/200 [30:19<17:05, 14.86s/it, loss=0.469, categorical_accuracy=0.848]
#
#
# Epoch 10:  66%|██████▌   | 132/200 [30:27<14:35, 12.88s/it, loss=0.469, categorical_accuracy=0.848]
#
#
# Epoch 10:  66%|██████▌   | 132/200 [30:27<14:35, 12.88s/it, loss=0.612, categorical_accuracy=0.79]
#
#
# Epoch 10:  66%|██████▋   | 133/200 [30:35<12:41, 11.36s/it, loss=0.612, categorical_accuracy=0.79]
#
#
# Epoch 10:  66%|██████▋   | 133/200 [30:35<12:41, 11.36s/it, loss=0.381, categorical_accuracy=0.885]
#
#
# Epoch 10:  67%|██████▋   | 134/200 [30:43<11:16, 10.25s/it, loss=0.381, categorical_accuracy=0.885]
#
#
# Epoch 10:  67%|██████▋   | 134/200 [30:43<11:16, 10.25s/it, loss=0.479, categorical_accuracy=0.826]
#
#
# Epoch 10:  68%|██████▊   | 135/200 [30:51<10:27,  9.65s/it, loss=0.479, categorical_accuracy=0.826]
#
#
# Epoch 10:  68%|██████▊   | 135/200 [30:51<10:27,  9.65s/it, loss=0.56, categorical_accuracy=0.81]
#
#
# Epoch 10:  68%|██████▊   | 136/200 [31:00<09:55,  9.30s/it, loss=0.56, categorical_accuracy=0.81]
#
#
# Epoch 10:  68%|██████▊   | 136/200 [31:00<09:55,  9.30s/it, loss=0.535, categorical_accuracy=0.819]
#
#
# Epoch 10:  68%|██████▊   | 137/200 [31:45<21:10, 20.16s/it, loss=0.535, categorical_accuracy=0.819]
#
#
# Epoch 10:  68%|██████▊   | 137/200 [31:45<21:10, 20.16s/it, loss=0.452, categorical_accuracy=0.866]
#
#
# Epoch 10:  69%|██████▉   | 138/200 [31:56<18:02, 17.46s/it, loss=0.452, categorical_accuracy=0.866]
#
#
# Epoch 10:  69%|██████▉   | 138/200 [31:56<18:02, 17.46s/it, loss=0.474, categorical_accuracy=0.833]
#
#
# Epoch 10:  70%|██████▉   | 139/200 [32:04<14:45, 14.52s/it, loss=0.474, categorical_accuracy=0.833]
#
#
# Epoch 10:  70%|██████▉   | 139/200 [32:04<14:45, 14.52s/it, loss=0.554, categorical_accuracy=0.819]
#
#
# Epoch 10:  70%|███████   | 140/200 [32:12<12:36, 12.61s/it, loss=0.554, categorical_accuracy=0.819]
#
#
# Epoch 10:  70%|███████   | 140/200 [32:12<12:36, 12.61s/it, loss=0.536, categorical_accuracy=0.807]
#
#
# Epoch 10:  70%|███████   | 141/200 [32:20<11:03, 11.25s/it, loss=0.536, categorical_accuracy=0.807]
#
#
# Epoch 10:  70%|███████   | 141/200 [32:20<11:03, 11.25s/it, loss=0.486, categorical_accuracy=0.843]
#
#
# Epoch 10:  71%|███████   | 142/200 [32:28<09:53, 10.23s/it, loss=0.486, categorical_accuracy=0.843]
#
#
# Epoch 10:  71%|███████   | 142/200 [32:28<09:53, 10.23s/it, loss=0.502, categorical_accuracy=0.833]
#
#
# Epoch 10:  72%|███████▏  | 143/200 [32:36<08:59,  9.47s/it, loss=0.502, categorical_accuracy=0.833]
#
#
# Epoch 10:  72%|███████▏  | 143/200 [32:36<08:59,  9.47s/it, loss=0.574, categorical_accuracy=0.828]
#
#
# Epoch 10:  72%|███████▏  | 144/200 [32:44<08:33,  9.18s/it, loss=0.574, categorical_accuracy=0.828]
#
#
# Epoch 10:  72%|███████▏  | 144/200 [32:44<08:33,  9.18s/it, loss=0.573, categorical_accuracy=0.819]
#
#
# Epoch 10:  72%|███████▎  | 145/200 [33:32<19:08, 20.87s/it, loss=0.573, categorical_accuracy=0.819]
#
#
# Epoch 10:  72%|███████▎  | 145/200 [33:32<19:08, 20.87s/it, loss=0.512, categorical_accuracy=0.829]
#
#
# Epoch 10:  73%|███████▎  | 146/200 [33:42<15:47, 17.55s/it, loss=0.512, categorical_accuracy=0.829]
#
#
# Epoch 10:  73%|███████▎  | 146/200 [33:42<15:47, 17.55s/it, loss=0.436, categorical_accuracy=0.864]
#
#
# Epoch 10:  74%|███████▎  | 147/200 [33:51<13:07, 14.86s/it, loss=0.436, categorical_accuracy=0.864]
#
#
# Epoch 10:  74%|███████▎  | 147/200 [33:51<13:07, 14.86s/it, loss=0.488, categorical_accuracy=0.839]
#
#
# Epoch 10:  74%|███████▍  | 148/200 [33:59<11:06, 12.81s/it, loss=0.488, categorical_accuracy=0.839]
#
#
# Epoch 10:  74%|███████▍  | 148/200 [33:59<11:06, 12.81s/it, loss=0.478, categorical_accuracy=0.848]
#
#
# Epoch 10:  74%|███████▍  | 149/200 [34:07<09:42, 11.42s/it, loss=0.478, categorical_accuracy=0.848]
#
#
# Epoch 10:  74%|███████▍  | 149/200 [34:07<09:42, 11.42s/it, loss=0.489, categorical_accuracy=0.859]
#
#
# Epoch 10:  75%|███████▌  | 150/200 [34:15<08:39, 10.39s/it, loss=0.489, categorical_accuracy=0.859]
#
#
# Epoch 10:  75%|███████▌  | 150/200 [34:15<08:39, 10.39s/it, loss=0.544, categorical_accuracy=0.81]
#
#
# Epoch 10:  76%|███████▌  | 151/200 [34:23<07:57,  9.75s/it, loss=0.544, categorical_accuracy=0.81]
#
#
# Epoch 10:  76%|███████▌  | 151/200 [34:23<07:57,  9.75s/it, loss=0.537, categorical_accuracy=0.82]
#
#
# Epoch 10:  76%|███████▌  | 152/200 [34:32<07:34,  9.46s/it, loss=0.537, categorical_accuracy=0.82]
#
#
# Epoch 10:  76%|███████▌  | 152/200 [34:32<07:34,  9.46s/it, loss=0.57, categorical_accuracy=0.825]
#
#
# Epoch 10:  76%|███████▋  | 153/200 [35:20<16:25, 20.97s/it, loss=0.57, categorical_accuracy=0.825]
#
#
# Epoch 10:  76%|███████▋  | 153/200 [35:20<16:25, 20.97s/it, loss=0.474, categorical_accuracy=0.831]
#
#
# Epoch 10:  77%|███████▋  | 154/200 [35:28<13:12, 17.22s/it, loss=0.474, categorical_accuracy=0.831]
#
#
# Epoch 10:  77%|███████▋  | 154/200 [35:28<13:12, 17.22s/it, loss=0.493, categorical_accuracy=0.833]
#
#
# Epoch 10:  78%|███████▊  | 155/200 [35:36<10:49, 14.44s/it, loss=0.493, categorical_accuracy=0.833]
#
#
# Epoch 10:  78%|███████▊  | 155/200 [35:36<10:49, 14.44s/it, loss=0.583, categorical_accuracy=0.796]
#
#
# Epoch 10:  78%|███████▊  | 156/200 [35:44<09:09, 12.48s/it, loss=0.583, categorical_accuracy=0.796]
#
#
# Epoch 10:  78%|███████▊  | 156/200 [35:44<09:09, 12.48s/it, loss=0.534, categorical_accuracy=0.816]
#
#
# Epoch 10:  78%|███████▊  | 157/200 [35:53<08:08, 11.35s/it, loss=0.534, categorical_accuracy=0.816]
#
#
# Epoch 10:  78%|███████▊  | 157/200 [35:53<08:08, 11.35s/it, loss=0.521, categorical_accuracy=0.836]
#
#
# Epoch 10:  79%|███████▉  | 158/200 [36:01<07:14, 10.34s/it, loss=0.521, categorical_accuracy=0.836]
#
#
# Epoch 10:  79%|███████▉  | 158/200 [36:01<07:14, 10.34s/it, loss=0.486, categorical_accuracy=0.843]
#
#
# Epoch 10:  80%|███████▉  | 159/200 [36:09<06:37,  9.69s/it, loss=0.486, categorical_accuracy=0.843]
#
#
# Epoch 10:  80%|███████▉  | 159/200 [36:09<06:37,  9.69s/it, loss=0.456, categorical_accuracy=0.84]
#
#
# Epoch 10:  80%|████████  | 160/200 [36:17<06:07,  9.18s/it, loss=0.456, categorical_accuracy=0.84]
#
#
# Epoch 10:  80%|████████  | 160/200 [36:17<06:07,  9.18s/it, loss=0.492, categorical_accuracy=0.83]
#
#
# Epoch 10:  80%|████████  | 161/200 [37:05<13:28, 20.72s/it, loss=0.492, categorical_accuracy=0.83]
#
#
# Epoch 10:  80%|████████  | 161/200 [37:05<13:28, 20.72s/it, loss=0.551, categorical_accuracy=0.819]
#
#
# Epoch 10:  81%|████████  | 162/200 [37:13<10:50, 17.12s/it, loss=0.551, categorical_accuracy=0.819]
#
#
# Epoch 10:  81%|████████  | 162/200 [37:13<10:50, 17.12s/it, loss=0.54, categorical_accuracy=0.831]
#
#
# Epoch 10:  82%|████████▏ | 163/200 [37:21<08:49, 14.30s/it, loss=0.54, categorical_accuracy=0.831]
#
#
# Epoch 10:  82%|████████▏ | 163/200 [37:21<08:49, 14.30s/it, loss=0.532, categorical_accuracy=0.828]
#
#
# Epoch 10:  82%|████████▏ | 164/200 [37:30<07:37, 12.72s/it, loss=0.532, categorical_accuracy=0.828]
#
#
# Epoch 10:  82%|████████▏ | 164/200 [37:30<07:37, 12.72s/it, loss=0.487, categorical_accuracy=0.826]
#
#
# Epoch 10:  82%|████████▎ | 165/200 [37:38<06:37, 11.37s/it, loss=0.487, categorical_accuracy=0.826]
#
#
# Epoch 10:  82%|████████▎ | 165/200 [37:38<06:37, 11.37s/it, loss=0.433, categorical_accuracy=0.856]
#
#
# Epoch 10:  83%|████████▎ | 166/200 [37:47<05:56, 10.49s/it, loss=0.433, categorical_accuracy=0.856]
#
#
# Epoch 10:  83%|████████▎ | 166/200 [37:47<05:56, 10.49s/it, loss=0.454, categorical_accuracy=0.853]
#
#
# Epoch 10:  84%|████████▎ | 167/200 [37:55<05:21,  9.74s/it, loss=0.454, categorical_accuracy=0.853]
#
#
# Epoch 10:  84%|████████▎ | 167/200 [37:55<05:21,  9.74s/it, loss=0.475, categorical_accuracy=0.843]
#
#
# Epoch 10:  84%|████████▍ | 168/200 [38:03<05:01,  9.42s/it, loss=0.475, categorical_accuracy=0.843]
#
#
# Epoch 10:  84%|████████▍ | 168/200 [38:03<05:01,  9.42s/it, loss=0.464, categorical_accuracy=0.841]
#
#
# Epoch 10:  84%|████████▍ | 169/200 [38:52<10:56, 21.18s/it, loss=0.464, categorical_accuracy=0.841]
#
#
# Epoch 10:  84%|████████▍ | 169/200 [38:52<10:56, 21.18s/it, loss=0.469, categorical_accuracy=0.841]
#
#
# Epoch 10:  85%|████████▌ | 170/200 [39:00<08:34, 17.15s/it, loss=0.469, categorical_accuracy=0.841]
#
#
# Epoch 10:  85%|████████▌ | 170/200 [39:00<08:34, 17.15s/it, loss=0.482, categorical_accuracy=0.836]
#
#
# Epoch 10:  86%|████████▌ | 171/200 [39:08<06:56, 14.37s/it, loss=0.482, categorical_accuracy=0.836]
#
#
# Epoch 10:  86%|████████▌ | 171/200 [39:08<06:56, 14.37s/it, loss=0.536, categorical_accuracy=0.815]
#
#
# Epoch 10:  86%|████████▌ | 172/200 [39:17<06:00, 12.87s/it, loss=0.536, categorical_accuracy=0.815]
#
#
# Epoch 10:  86%|████████▌ | 172/200 [39:17<06:00, 12.87s/it, loss=0.458, categorical_accuracy=0.845]
#
#
# Epoch 10:  86%|████████▋ | 173/200 [39:25<05:09, 11.48s/it, loss=0.458, categorical_accuracy=0.845]
#
#
# Epoch 10:  86%|████████▋ | 173/200 [39:25<05:09, 11.48s/it, loss=0.469, categorical_accuracy=0.844]
#
#
# Epoch 10:  87%|████████▋ | 174/200 [39:34<04:33, 10.51s/it, loss=0.469, categorical_accuracy=0.844]
#
#
# Epoch 10:  87%|████████▋ | 174/200 [39:34<04:33, 10.51s/it, loss=0.487, categorical_accuracy=0.841]
#
#
# Epoch 10:  88%|████████▊ | 175/200 [39:41<04:01,  9.65s/it, loss=0.487, categorical_accuracy=0.841]
#
#
# Epoch 10:  88%|████████▊ | 175/200 [39:41<04:01,  9.65s/it, loss=0.488, categorical_accuracy=0.858]
#
#
# Epoch 10:  88%|████████▊ | 176/200 [39:50<03:42,  9.26s/it, loss=0.488, categorical_accuracy=0.858]
#
#
# Epoch 10:  88%|████████▊ | 176/200 [39:50<03:42,  9.26s/it, loss=0.551, categorical_accuracy=0.821]
#
#
# Epoch 10:  88%|████████▊ | 177/200 [40:37<07:53, 20.59s/it, loss=0.551, categorical_accuracy=0.821]
#
#
# Epoch 10:  88%|████████▊ | 177/200 [40:37<07:53, 20.59s/it, loss=0.455, categorical_accuracy=0.859]
#
#
# Epoch 10:  89%|████████▉ | 178/200 [40:45<06:09, 16.79s/it, loss=0.455, categorical_accuracy=0.859]
#
#
# Epoch 10:  89%|████████▉ | 178/200 [40:45<06:09, 16.79s/it, loss=0.445, categorical_accuracy=0.85]
#
#
# Epoch 10:  90%|████████▉ | 179/200 [40:53<05:00, 14.29s/it, loss=0.445, categorical_accuracy=0.85]
#
#
# Epoch 10:  90%|████████▉ | 179/200 [40:53<05:00, 14.29s/it, loss=0.564, categorical_accuracy=0.807]
#
#
# Epoch 10:  90%|█████████ | 180/200 [41:01<04:08, 12.43s/it, loss=0.564, categorical_accuracy=0.807]
#
#
# Epoch 10:  90%|█████████ | 180/200 [41:01<04:08, 12.43s/it, loss=0.473, categorical_accuracy=0.819]
#
#
# Epoch 10:  90%|█████████ | 181/200 [41:09<03:33, 11.22s/it, loss=0.473, categorical_accuracy=0.819]
#
#
# Epoch 10:  90%|█████████ | 181/200 [41:09<03:33, 11.22s/it, loss=0.493, categorical_accuracy=0.835]
#
#
# Epoch 10:  91%|█████████ | 182/200 [41:17<03:01, 10.10s/it, loss=0.493, categorical_accuracy=0.835]
#
#
# Epoch 10:  91%|█████████ | 182/200 [41:17<03:01, 10.10s/it, loss=0.576, categorical_accuracy=0.781]
#
#
# Epoch 10:  92%|█████████▏| 183/200 [41:25<02:43,  9.62s/it, loss=0.576, categorical_accuracy=0.781]
#
#
# Epoch 10:  92%|█████████▏| 183/200 [41:25<02:43,  9.62s/it, loss=0.439, categorical_accuracy=0.851]
#
#
# Epoch 10:  92%|█████████▏| 184/200 [41:34<02:26,  9.18s/it, loss=0.439, categorical_accuracy=0.851]
#
#
# Epoch 10:  92%|█████████▏| 184/200 [41:34<02:26,  9.18s/it, loss=0.493, categorical_accuracy=0.833]
#
#
# Epoch 10:  92%|█████████▎| 185/200 [42:19<05:00, 20.03s/it, loss=0.493, categorical_accuracy=0.833]
#
#
# Epoch 10:  92%|█████████▎| 185/200 [42:19<05:00, 20.03s/it, loss=0.445, categorical_accuracy=0.844]
#
#
# Epoch 10:  93%|█████████▎| 186/200 [42:26<03:45, 16.07s/it, loss=0.445, categorical_accuracy=0.844]
#
#
# Epoch 10:  93%|█████████▎| 186/200 [42:26<03:45, 16.07s/it, loss=0.542, categorical_accuracy=0.818]
#
#
# Epoch 10:  94%|█████████▎| 187/200 [42:31<02:45, 12.75s/it, loss=0.542, categorical_accuracy=0.818]
#
#
# Epoch 10:  94%|█████████▎| 187/200 [42:31<02:45, 12.75s/it, loss=0.523, categorical_accuracy=0.83]
#
#
# Epoch 10:  94%|█████████▍| 188/200 [42:44<02:35, 12.93s/it, loss=0.523, categorical_accuracy=0.83]
#
#
# Epoch 10:  94%|█████████▍| 188/200 [42:44<02:35, 12.93s/it, loss=0.427, categorical_accuracy=0.856]
#
#
# Epoch 10:  94%|█████████▍| 189/200 [42:49<01:56, 10.57s/it, loss=0.427, categorical_accuracy=0.856]
#
#
# Epoch 10:  94%|█████████▍| 189/200 [42:49<01:56, 10.57s/it, loss=0.499, categorical_accuracy=0.844]
#
#
# Epoch 10:  95%|█████████▌| 190/200 [42:54<01:28,  8.88s/it, loss=0.499, categorical_accuracy=0.844]
#
#
# Epoch 10:  95%|█████████▌| 190/200 [42:54<01:28,  8.88s/it, loss=0.468, categorical_accuracy=0.845]
#
#
# Epoch 10:  96%|█████████▌| 191/200 [42:59<01:08,  7.64s/it, loss=0.468, categorical_accuracy=0.845]
#
#
# Epoch 10:  96%|█████████▌| 191/200 [42:59<01:08,  7.64s/it, loss=0.46, categorical_accuracy=0.855]
#
#
# Epoch 10:  96%|█████████▌| 192/200 [43:04<00:55,  6.88s/it, loss=0.46, categorical_accuracy=0.855]
#
#
# Epoch 10:  96%|█████████▌| 192/200 [43:04<00:55,  6.88s/it, loss=0.461, categorical_accuracy=0.848]
#
#
# Epoch 10:  96%|█████████▋| 193/200 [44:01<02:34, 22.01s/it, loss=0.461, categorical_accuracy=0.848]
#
#
# Epoch 10:  96%|█████████▋| 193/200 [44:01<02:34, 22.01s/it, loss=0.547, categorical_accuracy=0.825]
#
#
# Epoch 10:  97%|█████████▋| 194/200 [44:08<01:43, 17.33s/it, loss=0.547, categorical_accuracy=0.825]
#
#
# Epoch 10:  97%|█████████▋| 194/200 [44:08<01:43, 17.33s/it, loss=0.586, categorical_accuracy=0.812]
#
#
# Epoch 10:  98%|█████████▊| 195/200 [44:12<01:06, 13.38s/it, loss=0.586, categorical_accuracy=0.812]
#
#
# Epoch 10:  98%|█████████▊| 195/200 [44:12<01:06, 13.38s/it, loss=0.457, categorical_accuracy=0.843]
#
#
# Epoch 10:  98%|█████████▊| 196/200 [44:19<00:46, 11.56s/it, loss=0.457, categorical_accuracy=0.843]
#
#
# Epoch 10:  98%|█████████▊| 196/200 [44:19<00:46, 11.56s/it, loss=0.466, categorical_accuracy=0.849]
#
#
# Epoch 10:  98%|█████████▊| 197/200 [44:23<00:27,  9.22s/it, loss=0.466, categorical_accuracy=0.849]
#
#
# Epoch 10:  98%|█████████▊| 197/200 [44:23<00:27,  9.22s/it, loss=0.472, categorical_accuracy=0.834]
#
#
# Epoch 10:  99%|█████████▉| 198/200 [44:27<00:15,  7.58s/it, loss=0.472, categorical_accuracy=0.834]
#
#
# Epoch 10:  99%|█████████▉| 198/200 [44:27<00:15,  7.58s/it, loss=0.436, categorical_accuracy=0.853]
#
#
# Epoch 10: 100%|█████████▉| 199/200 [44:30<00:06,  6.43s/it, loss=0.436, categorical_accuracy=0.853]
#
#
# Epoch 10: 100%|█████████▉| 199/200 [44:30<00:06,  6.43s/it, loss=0.527, categorical_accuracy=0.815]
#
#
# Epoch 10: 100%|██████████| 200/200 [49:38<00:00, 96.87s/it, loss=0.527, categorical_accuracy=0.815]
#
#
# Epoch 10: 100%|██████████| 200/200 [49:38<00:00, 14.89s/it, loss=0.501, categorical_accuracy=0.834]
# Finished.

# %%
/content/drive/My Drive/CLASSIFICATION/Few Shot/logs /maml_aircraft
